# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import re

# %%
import re
import matplotlib.pyplot as plt

# Define the path to your log file
log_file_path = 'output.log'

# Initialize a dictionary to store the count of each reaction type
reaction_counts = {
    'f1': 0,
    'f2': 0,
    'f3': 0,
    'f4': 0
}

# Initialize dictionaries to store distances for each type of reaction
reaction_distances = {
    'f1': [],
    'f2': [],
    'f3': [],
    'f4': []
}

# Define a mapping from log reaction types to our reaction types
reaction_map = {
    'reacUM': 'f1',
    'reacMU': 'f2',
    'reacUA': 'f3',
    'reacAU': 'f4'
}

# Open the log file and read its contents
with open(log_file_path, 'r') as file:
    lines = file.readlines()

# Define a regex pattern to match lines containing reacting atom IDs and reaction types
pattern = re.compile(r'reacted_atom_IDs: (reac\w+) (\d+) (\d+)')

# Loop through each line and search for the pattern
for line in lines:
    match = pattern.search(line)
    if match:
        # Extract the reaction type and atom IDs
        reaction_type = match.group(1)
        atom_id_1 = int(match.group(2))
        atom_id_2 = int(match.group(3))
        
        # Calculate distance
        distance = abs(atom_id_1 - atom_id_2)
        
        # Get the corresponding reaction type from the map
        reaction_key = reaction_map[reaction_type]
        
        # Append distance to the appropriate reaction type
        reaction_distances[reaction_key].append(distance)
        
        # Increment the count for the corresponding reaction type
        reaction_counts[reaction_key] += 1

labels = {
    'f1': 'Reaction A to U',
    'f2': 'Reaction M to U',
    'f3': 'Reaction U to A',
    'f4': 'Reaction U to M'
}

# Plot histograms of distances for each reaction type
plt.figure(figsize=(12, 8))
for reaction_type, distances in reaction_distances.items():
    plt.hist(distances, bins=20, alpha=0.7, label=f'{labels[reaction_type]}', density=False)

plt.title('Histogram of Distances for Each Reaction Type')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# Print the counts of each reaction type
for reaction_type, count in reaction_counts.items():
    print(f'{labels[reaction_type]} count: {count}')
# Out:
# Reaction A to U count: 220
# Reaction M to U count: 185
# Reaction U to A count: 186
# Reaction U to M count: 177

# %%
import re
import matplotlib.pyplot as plt

# Define the path to your log file
log_file_path = 'output.log'

# Initialize a dictionary to store the count of each reaction type
reaction_counts = {
    'f1': 0,
    'f2': 0,
    'f3': 0,
    'f4': 0
}

# Initialize dictionaries to store distances for each type of reaction
reaction_distances = {
    'f1': [],
    'f2': [],
    'f3': [],
    'f4': []
}

# Define a mapping from log reaction types to our reaction types
reaction_map = {
    'reacAU': 'f1',
    'reacMU': 'f2',
    'reacUA': 'f3',
    'reacUM': 'f4'
}

# Open the log file and read its contents
with open(log_file_path, 'r') as file:
    lines = file.readlines()

# Define a regex pattern to match lines containing reacting atom IDs and reaction types
pattern = re.compile(r'reacted_atom_IDs: (reac\w+) (\d+) (\d+)')

# List to store reaction data for further use if needed
reaction_data = []

# Loop through each line and search for the pattern
for line in lines:
    match = pattern.search(line)
    if match:
        # Extract the reaction type and atom IDs
        reaction_type = match.group(1)
        atom_id_1 = int(match.group(2))
        atom_id_2 = int(match.group(3))
        
        # Calculate distance
        distance = abs(atom_id_1 - atom_id_2)
        
        # Get the corresponding reaction type from the map
        reaction_key = reaction_map[reaction_type]
        
        # Check if this reaction data already exists
        if (reaction_type, atom_id_1, atom_id_2, distance) not in reaction_data:
            # Append distance to the appropriate reaction type
            reaction_distances[reaction_key].append(distance)
            
            # Increment the count for the corresponding reaction type
            reaction_counts[reaction_key] += 1
    
            # Store the reaction data (including reaction type)
            reaction_data.append((reaction_type, atom_id_1, atom_id_2, distance))


labels = {
    'f1': 'Reaction A to U',
    'f2': 'Reaction M to U',
    'f3': 'Reaction U to A',
    'f4': 'Reaction U to M'
}

# Plot histograms of distances for each reaction type
plt.figure(figsize=(12, 8))
for reaction_type, distances in reaction_distances.items():
    plt.hist(distances, bins=20, alpha=0.7, label=f'{labels[reaction_type]}', density=True)

plt.title('Histogram of Distances for Each Reaction Type')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# Print the counts of each reaction type
for reaction_type, count in reaction_counts.items():
    print(f'{labels[reaction_type]} count: {count}')

# Print stored reaction data if needed
for reaction in reaction_data:
    print(f'Reaction {reaction[0]} between atom IDs {reaction[1]} and {reaction[2]} with distance {reaction[3]}')
# Out:
# Reaction A to U count: 152
# Reaction M to U count: 158
# Reaction U to A count: 165
# Reaction U to M count: 188
# Reaction reacMU between atom IDs 11 and 4 with distance 7
# Reaction reacUM between atom IDs 79 and 75 with distance 4
# Reaction reacAU between atom IDs 21 and 16 with distance 5
# Reaction reacMU between atom IDs 23 and 19 with distance 4
# Reaction reacUA between atom IDs 25 and 21 with distance 4
# Reaction reacAU between atom IDs 49 and 53 with distance 4
# Reaction reacAU between atom IDs 34 and 25 with distance 9
# Reaction reacMU between atom IDs 65 and 61 with distance 4
# Reaction reacMU between atom IDs 57 and 53 with distance 4
# Reaction reacUA between atom IDs 69 and 65 with distance 4
# Reaction reacUM between atom IDs 59 and 63 with distance 4
# Reaction reacUM between atom IDs 35 and 31 with distance 4
# Reaction reacMU between atom IDs 9 and 4 with distance 5
# Reaction reacUA between atom IDs 8 and 12 with distance 4
# Reaction reacAU between atom IDs 30 and 26 with distance 4
# Reaction reacMU between atom IDs 8 and 3 with distance 5
# Reaction reacMU between atom IDs 43 and 39 with distance 4
# Reaction reacAU between atom IDs 30 and 35 with distance 5
# Reaction reacMU between atom IDs 53 and 46 with distance 7
# Reaction reacUA between atom IDs 67 and 71 with distance 4
# Reaction reacUA between atom IDs 1 and 18 with distance 17
# Reaction reacUM between atom IDs 14 and 18 with distance 4
# Reaction reacUM between atom IDs 58 and 62 with distance 4
# Reaction reacUA between atom IDs 25 and 8 with distance 17
# Reaction reacAU between atom IDs 61 and 55 with distance 6
# Reaction reacAU between atom IDs 74 and 78 with distance 4
# Reaction reacMU between atom IDs 74 and 70 with distance 4
# Reaction reacAU between atom IDs 3 and 7 with distance 4
# Reaction reacMU between atom IDs 50 and 25 with distance 25
# Reaction reacAU between atom IDs 52 and 56 with distance 4
# Reaction reacAU between atom IDs 37 and 41 with distance 4
# Reaction reacUA between atom IDs 35 and 30 with distance 5
# Reaction reacMU between atom IDs 24 and 28 with distance 4
# Reaction reacMU between atom IDs 37 and 33 with distance 4
# Reaction reacUA between atom IDs 75 and 79 with distance 4
# Reaction reacAU between atom IDs 43 and 29 with distance 14
# Reaction reacMU between atom IDs 33 and 29 with distance 4
# Reaction reacAU between atom IDs 68 and 64 with distance 4
# Reaction reacAU between atom IDs 44 and 40 with distance 4
# Reaction reacMU between atom IDs 4 and 10 with distance 6
# Reaction reacUM between atom IDs 73 and 78 with distance 5
# Reaction reacAU between atom IDs 39 and 35 with distance 4
# Reaction reacUA between atom IDs 66 and 77 with distance 11
# Reaction reacMU between atom IDs 6 and 2 with distance 4
# Reaction reacUM between atom IDs 13 and 17 with distance 4
# Reaction reacUA between atom IDs 9 and 2 with distance 7
# Reaction reacMU between atom IDs 44 and 40 with distance 4
# Reaction reacUM between atom IDs 71 and 67 with distance 4
# Reaction reacAU between atom IDs 50 and 54 with distance 4
# Reaction reacMU between atom IDs 51 and 47 with distance 4
# Reaction reacUM between atom IDs 31 and 27 with distance 4
# Reaction reacUM between atom IDs 35 and 30 with distance 5
# Reaction reacUM between atom IDs 8 and 3 with distance 5
# Reaction reacUA between atom IDs 78 and 56 with distance 22
# Reaction reacUA between atom IDs 66 and 60 with distance 6
# Reaction reacUA between atom IDs 79 and 72 with distance 7
# Reaction reacUM between atom IDs 9 and 5 with distance 4
# Reaction reacUA between atom IDs 48 and 57 with distance 9
# Reaction reacUM between atom IDs 72 and 61 with distance 11
# Reaction reacUA between atom IDs 68 and 64 with distance 4
# Reaction reacUM between atom IDs 58 and 54 with distance 4
# Reaction reacUM between atom IDs 15 and 10 with distance 5
# Reaction reacUM between atom IDs 77 and 64 with distance 13
# Reaction reacAU between atom IDs 28 and 41 with distance 13
# Reaction reacMU between atom IDs 37 and 41 with distance 4
# Reaction reacUM between atom IDs 35 and 40 with distance 5
# Reaction reacUM between atom IDs 48 and 43 with distance 5
# Reaction reacUA between atom IDs 48 and 52 with distance 4
# Reaction reacUM between atom IDs 27 and 50 with distance 23
# Reaction reacAU between atom IDs 16 and 12 with distance 4
# Reaction reacUM between atom IDs 68 and 73 with distance 5
# Reaction reacUA between atom IDs 56 and 51 with distance 5
# Reaction reacUA between atom IDs 40 and 36 with distance 4
# Reaction reacUA between atom IDs 10 and 6 with distance 4
# Reaction reacUM between atom IDs 18 and 22 with distance 4
# Reaction reacUM between atom IDs 73 and 66 with distance 7
# Reaction reacAU between atom IDs 54 and 60 with distance 6
# Reaction reacAU between atom IDs 29 and 49 with distance 20
# Reaction reacMU between atom IDs 3 and 7 with distance 4
# Reaction reacUA between atom IDs 15 and 19 with distance 4
# Reaction reacUM between atom IDs 64 and 49 with distance 15
# Reaction reacUM between atom IDs 31 and 36 with distance 5
# Reaction reacMU between atom IDs 32 and 61 with distance 29
# Reaction reacAU between atom IDs 50 and 56 with distance 6
# Reaction reacMU between atom IDs 67 and 42 with distance 25
# Reaction reacAU between atom IDs 7 and 11 with distance 4
# Reaction reacUM between atom IDs 48 and 26 with distance 22
# Reaction reacUM between atom IDs 48 and 52 with distance 4
# Reaction reacMU between atom IDs 54 and 60 with distance 6
# Reaction reacAU between atom IDs 46 and 80 with distance 34
# Reaction reacUA between atom IDs 73 and 33 with distance 40
# Reaction reacAU between atom IDs 67 and 71 with distance 4
# Reaction reacUA between atom IDs 77 and 35 with distance 42
# Reaction reacUA between atom IDs 64 and 60 with distance 4
# Reaction reacUM between atom IDs 8 and 12 with distance 4
# Reaction reacAU between atom IDs 53 and 57 with distance 4
# Reaction reacMU between atom IDs 28 and 33 with distance 5
# Reaction reacMU between atom IDs 12 and 16 with distance 4
# Reaction reacMU between atom IDs 50 and 28 with distance 22
# Reaction reacUM between atom IDs 15 and 11 with distance 4
# Reaction reacAU between atom IDs 54 and 58 with distance 4
# Reaction reacAU between atom IDs 54 and 47 with distance 7
# Reaction reacAU between atom IDs 13 and 1 with distance 12
# Reaction reacUA between atom IDs 46 and 52 with distance 6
# Reaction reacUA between atom IDs 10 and 16 with distance 6
# Reaction reacUA between atom IDs 79 and 74 with distance 5
# Reaction reacUM between atom IDs 78 and 74 with distance 4
# Reaction reacUM between atom IDs 66 and 70 with distance 4
# Reaction reacAU between atom IDs 31 and 27 with distance 4
# Reaction reacAU between atom IDs 42 and 46 with distance 4
# Reaction reacAU between atom IDs 32 and 36 with distance 4
# Reaction reacMU between atom IDs 28 and 24 with distance 4
# Reaction reacMU between atom IDs 31 and 35 with distance 4
# Reaction reacUA between atom IDs 26 and 21 with distance 5
# Reaction reacUM between atom IDs 11 and 6 with distance 5
# Reaction reacUM between atom IDs 15 and 30 with distance 15
# Reaction reacUM between atom IDs 74 and 80 with distance 6
# Reaction reacMU between atom IDs 38 and 31 with distance 7
# Reaction reacUA between atom IDs 26 and 31 with distance 5
# Reaction reacUM between atom IDs 8 and 4 with distance 4
# Reaction reacAU between atom IDs 65 and 72 with distance 7
# Reaction reacUA between atom IDs 46 and 51 with distance 5
# Reaction reacUM between atom IDs 26 and 22 with distance 4
# Reaction reacUA between atom IDs 36 and 40 with distance 4
# Reaction reacUM between atom IDs 37 and 51 with distance 14
# Reaction reacUA between atom IDs 45 and 50 with distance 5
# Reaction reacUM between atom IDs 74 and 69 with distance 5
# Reaction reacUM between atom IDs 70 and 46 with distance 24
# Reaction reacMU between atom IDs 59 and 63 with distance 4
# Reaction reacUM between atom IDs 80 and 52 with distance 28
# Reaction reacMU between atom IDs 63 and 67 with distance 4
# Reaction reacMU between atom IDs 54 and 50 with distance 4
# Reaction reacMU between atom IDs 29 and 33 with distance 4
# Reaction reacUM between atom IDs 60 and 66 with distance 6
# Reaction reacUA between atom IDs 26 and 30 with distance 4
# Reaction reacUA between atom IDs 53 and 41 with distance 12
# Reaction reacMU between atom IDs 50 and 61 with distance 11
# Reaction reacAU between atom IDs 50 and 66 with distance 16
# Reaction reacUM between atom IDs 60 and 65 with distance 5
# Reaction reacUA between atom IDs 70 and 58 with distance 12
# Reaction reacMU between atom IDs 71 and 55 with distance 16
# Reaction reacUA between atom IDs 22 and 27 with distance 5
# Reaction reacAU between atom IDs 19 and 15 with distance 4
# Reaction reacAU between atom IDs 18 and 10 with distance 8
# Reaction reacUA between atom IDs 45 and 49 with distance 4
# Reaction reacUM between atom IDs 53 and 48 with distance 5
# Reaction reacUM between atom IDs 5 and 14 with distance 9
# Reaction reacUM between atom IDs 46 and 41 with distance 5
# Reaction reacUA between atom IDs 14 and 9 with distance 5
# Reaction reacAU between atom IDs 47 and 55 with distance 8
# Reaction reacMU between atom IDs 53 and 49 with distance 4
# Reaction reacMU between atom IDs 3 and 9 with distance 6
# Reaction reacUA between atom IDs 56 and 61 with distance 5
# Reaction reacAU between atom IDs 76 and 80 with distance 4
# Reaction reacUM between atom IDs 53 and 57 with distance 4
# Reaction reacUM between atom IDs 16 and 20 with distance 4
# Reaction reacUM between atom IDs 26 and 30 with distance 4
# Reaction reacUM between atom IDs 14 and 10 with distance 4
# Reaction reacAU between atom IDs 46 and 42 with distance 4
# Reaction reacMU between atom IDs 18 and 12 with distance 6
# Reaction reacMU between atom IDs 9 and 15 with distance 6
# Reaction reacMU between atom IDs 28 and 32 with distance 4
# Reaction reacAU between atom IDs 6 and 10 with distance 4
# Reaction reacUA between atom IDs 7 and 11 with distance 4
# Reaction reacUA between atom IDs 1 and 15 with distance 14
# Reaction reacAU between atom IDs 36 and 40 with distance 4
# Reaction reacUA between atom IDs 56 and 64 with distance 8
# Reaction reacUM between atom IDs 17 and 54 with distance 37
# Reaction reacUM between atom IDs 57 and 61 with distance 4
# Reaction reacUM between atom IDs 22 and 75 with distance 53
# Reaction reacMU between atom IDs 69 and 73 with distance 4
# Reaction reacUM between atom IDs 33 and 11 with distance 22
# Reaction reacMU between atom IDs 70 and 66 with distance 4
# Reaction reacUA between atom IDs 39 and 46 with distance 7
# Reaction reacMU between atom IDs 37 and 46 with distance 9
# Reaction reacMU between atom IDs 34 and 49 with distance 15
# Reaction reacUA between atom IDs 31 and 35 with distance 4
# Reaction reacUA between atom IDs 14 and 18 with distance 4
# Reaction reacUA between atom IDs 30 and 34 with distance 4
# Reaction reacMU between atom IDs 46 and 42 with distance 4
# Reaction reacUA between atom IDs 77 and 73 with distance 4
# Reaction reacMU between atom IDs 47 and 51 with distance 4
# Reaction reacUM between atom IDs 44 and 40 with distance 4
# Reaction reacUM between atom IDs 24 and 29 with distance 5
# Reaction reacUA between atom IDs 61 and 66 with distance 5
# Reaction reacUA between atom IDs 16 and 12 with distance 4
# Reaction reacUA between atom IDs 28 and 32 with distance 4
# Reaction reacMU between atom IDs 15 and 11 with distance 4
# Reaction reacUA between atom IDs 52 and 57 with distance 5
# Reaction reacAU between atom IDs 21 and 17 with distance 4
# Reaction reacMU between atom IDs 68 and 64 with distance 4
# Reaction reacUM between atom IDs 11 and 5 with distance 6
# Reaction reacAU between atom IDs 15 and 11 with distance 4
# Reaction reacUA between atom IDs 56 and 52 with distance 4
# Reaction reacMU between atom IDs 7 and 11 with distance 4
# Reaction reacUM between atom IDs 26 and 32 with distance 6
# Reaction reacUM between atom IDs 5 and 12 with distance 7
# Reaction reacUA between atom IDs 23 and 19 with distance 4
# Reaction reacUA between atom IDs 58 and 53 with distance 5
# Reaction reacUM between atom IDs 57 and 53 with distance 4
# Reaction reacUA between atom IDs 57 and 62 with distance 5
# Reaction reacUA between atom IDs 56 and 65 with distance 9
# Reaction reacUM between atom IDs 64 and 78 with distance 14
# Reaction reacUM between atom IDs 29 and 34 with distance 5
# Reaction reacUA between atom IDs 51 and 47 with distance 4
# Reaction reacUA between atom IDs 21 and 17 with distance 4
# Reaction reacUA between atom IDs 70 and 63 with distance 7
# Reaction reacUA between atom IDs 51 and 55 with distance 4
# Reaction reacMU between atom IDs 71 and 66 with distance 5
# Reaction reacUM between atom IDs 72 and 48 with distance 24
# Reaction reacUM between atom IDs 70 and 74 with distance 4
# Reaction reacMU between atom IDs 79 and 47 with distance 32
# Reaction reacUA between atom IDs 64 and 58 with distance 6
# Reaction reacAU between atom IDs 50 and 72 with distance 22
# Reaction reacAU between atom IDs 47 and 51 with distance 4
# Reaction reacUM between atom IDs 73 and 56 with distance 17
# Reaction reacUM between atom IDs 21 and 25 with distance 4
# Reaction reacUM between atom IDs 70 and 63 with distance 7
# Reaction reacUM between atom IDs 30 and 34 with distance 4
# Reaction reacUA between atom IDs 74 and 78 with distance 4
# Reaction reacUM between atom IDs 76 and 72 with distance 4
# Reaction reacAU between atom IDs 15 and 10 with distance 5
# Reaction reacUM between atom IDs 26 and 20 with distance 6
# Reaction reacAU between atom IDs 16 and 21 with distance 5
# Reaction reacAU between atom IDs 24 and 20 with distance 4
# Reaction reacAU between atom IDs 71 and 75 with distance 4
# Reaction reacUA between atom IDs 27 and 23 with distance 4
# Reaction reacAU between atom IDs 29 and 25 with distance 4
# Reaction reacUA between atom IDs 28 and 24 with distance 4
# Reaction reacUM between atom IDs 48 and 44 with distance 4
# Reaction reacUA between atom IDs 61 and 50 with distance 11
# Reaction reacAU between atom IDs 69 and 64 with distance 5
# Reaction reacAU between atom IDs 43 and 48 with distance 5
# Reaction reacUM between atom IDs 36 and 41 with distance 5
# Reaction reacMU between atom IDs 17 and 46 with distance 29
# Reaction reacMU between atom IDs 15 and 8 with distance 7
# Reaction reacUM between atom IDs 2 and 37 with distance 35
# Reaction reacMU between atom IDs 54 and 65 with distance 11
# Reaction reacUM between atom IDs 6 and 1 with distance 5
# Reaction reacUA between atom IDs 22 and 17 with distance 5
# Reaction reacUM between atom IDs 34 and 48 with distance 14
# Reaction reacUA between atom IDs 39 and 43 with distance 4
# Reaction reacUM between atom IDs 26 and 40 with distance 14
# Reaction reacAU between atom IDs 77 and 71 with distance 6
# Reaction reacUM between atom IDs 63 and 49 with distance 14
# Reaction reacAU between atom IDs 65 and 49 with distance 16
# Reaction reacAU between atom IDs 47 and 59 with distance 12
# Reaction reacAU between atom IDs 38 and 43 with distance 5
# Reaction reacUM between atom IDs 29 and 25 with distance 4
# Reaction reacUM between atom IDs 24 and 31 with distance 7
# Reaction reacAU between atom IDs 58 and 53 with distance 5
# Reaction reacUA between atom IDs 48 and 54 with distance 6
# Reaction reacUA between atom IDs 22 and 28 with distance 6
# Reaction reacAU between atom IDs 38 and 26 with distance 12
# Reaction reacAU between atom IDs 47 and 41 with distance 6
# Reaction reacMU between atom IDs 65 and 60 with distance 5
# Reaction reacUM between atom IDs 57 and 49 with distance 8
# Reaction reacUM between atom IDs 37 and 41 with distance 4
# Reaction reacMU between atom IDs 65 and 28 with distance 37
# Reaction reacAU between atom IDs 29 and 33 with distance 4
# Reaction reacMU between atom IDs 18 and 14 with distance 4
# Reaction reacMU between atom IDs 66 and 71 with distance 5
# Reaction reacAU between atom IDs 75 and 79 with distance 4
# Reaction reacMU between atom IDs 65 and 51 with distance 14
# Reaction reacAU between atom IDs 71 and 49 with distance 22
# Reaction reacUM between atom IDs 27 and 31 with distance 4
# Reaction reacAU between atom IDs 63 and 43 with distance 20
# Reaction reacAU between atom IDs 66 and 41 with distance 25
# Reaction reacUM between atom IDs 27 and 23 with distance 4
# Reaction reacAU between atom IDs 32 and 18 with distance 14
# Reaction reacUA between atom IDs 50 and 45 with distance 5
# Reaction reacMU between atom IDs 68 and 79 with distance 11
# Reaction reacUA between atom IDs 22 and 44 with distance 22
# Reaction reacUA between atom IDs 16 and 20 with distance 4
# Reaction reacUA between atom IDs 59 and 55 with distance 4
# Reaction reacMU between atom IDs 15 and 45 with distance 30
# Reaction reacUA between atom IDs 37 and 14 with distance 23
# Reaction reacUM between atom IDs 52 and 56 with distance 4
# Reaction reacAU between atom IDs 28 and 24 with distance 4
# Reaction reacMU between atom IDs 15 and 19 with distance 4
# Reaction reacMU between atom IDs 39 and 7 with distance 32
# Reaction reacUA between atom IDs 57 and 64 with distance 7
# Reaction reacUA between atom IDs 74 and 79 with distance 5
# Reaction reacUA between atom IDs 25 and 19 with distance 6
# Reaction reacMU between atom IDs 29 and 18 with distance 11
# Reaction reacMU between atom IDs 20 and 16 with distance 4
# Reaction reacUA between atom IDs 5 and 1 with distance 4
# Reaction reacUM between atom IDs 56 and 60 with distance 4
# Reaction reacAU between atom IDs 72 and 76 with distance 4
# Reaction reacAU between atom IDs 19 and 23 with distance 4
# Reaction reacUA between atom IDs 50 and 46 with distance 4
# Reaction reacMU between atom IDs 9 and 13 with distance 4
# Reaction reacAU between atom IDs 9 and 5 with distance 4
# Reaction reacUM between atom IDs 47 and 43 with distance 4
# Reaction reacMU between atom IDs 8 and 12 with distance 4
# Reaction reacUA between atom IDs 60 and 50 with distance 10
# Reaction reacMU between atom IDs 36 and 40 with distance 4
# Reaction reacAU between atom IDs 62 and 48 with distance 14
# Reaction reacMU between atom IDs 49 and 5 with distance 44
# Reaction reacMU between atom IDs 56 and 52 with distance 4
# Reaction reacAU between atom IDs 65 and 61 with distance 4
# Reaction reacMU between atom IDs 55 and 80 with distance 25
# Reaction reacUA between atom IDs 57 and 52 with distance 5
# Reaction reacUA between atom IDs 68 and 72 with distance 4
# Reaction reacAU between atom IDs 37 and 45 with distance 8
# Reaction reacMU between atom IDs 39 and 35 with distance 4
# Reaction reacUA between atom IDs 24 and 20 with distance 4
# Reaction reacUM between atom IDs 26 and 7 with distance 19
# Reaction reacUA between atom IDs 4 and 8 with distance 4
# Reaction reacUA between atom IDs 60 and 56 with distance 4
# Reaction reacAU between atom IDs 55 and 51 with distance 4
# Reaction reacUM between atom IDs 23 and 27 with distance 4
# Reaction reacUA between atom IDs 65 and 70 with distance 5
# Reaction reacUA between atom IDs 42 and 25 with distance 17
# Reaction reacUM between atom IDs 48 and 15 with distance 33
# Reaction reacUA between atom IDs 47 and 14 with distance 33
# Reaction reacUM between atom IDs 5 and 11 with distance 6
# Reaction reacUM between atom IDs 12 and 8 with distance 4
# Reaction reacAU between atom IDs 53 and 59 with distance 6
# Reaction reacUA between atom IDs 35 and 39 with distance 4
# Reaction reacMU between atom IDs 72 and 76 with distance 4
# Reaction reacUM between atom IDs 23 and 28 with distance 5
# Reaction reacUM between atom IDs 60 and 56 with distance 4
# Reaction reacUM between atom IDs 10 and 25 with distance 15
# Reaction reacAU between atom IDs 36 and 30 with distance 6
# Reaction reacUM between atom IDs 73 and 69 with distance 4
# Reaction reacMU between atom IDs 55 and 51 with distance 4
# Reaction reacUM between atom IDs 57 and 63 with distance 6
# Reaction reacUM between atom IDs 2 and 8 with distance 6
# Reaction reacUM between atom IDs 10 and 5 with distance 5
# Reaction reacUA between atom IDs 61 and 55 with distance 6
# Reaction reacMU between atom IDs 13 and 18 with distance 5
# Reaction reacUM between atom IDs 12 and 7 with distance 5
# Reaction reacMU between atom IDs 13 and 9 with distance 4
# Reaction reacUA between atom IDs 24 and 29 with distance 5
# Reaction reacAU between atom IDs 59 and 64 with distance 5
# Reaction reacUA between atom IDs 67 and 58 with distance 9
# Reaction reacMU between atom IDs 47 and 43 with distance 4
# Reaction reacUA between atom IDs 17 and 22 with distance 5
# Reaction reacAU between atom IDs 56 and 61 with distance 5
# Reaction reacUM between atom IDs 69 and 65 with distance 4
# Reaction reacAU between atom IDs 13 and 17 with distance 4
# Reaction reacUM between atom IDs 15 and 21 with distance 6
# Reaction reacAU between atom IDs 76 and 72 with distance 4
# Reaction reacUM between atom IDs 4 and 12 with distance 8
# Reaction reacAU between atom IDs 13 and 8 with distance 5
# Reaction reacMU between atom IDs 66 and 62 with distance 4
# Reaction reacMU between atom IDs 66 and 61 with distance 5
# Reaction reacAU between atom IDs 32 and 42 with distance 10
# Reaction reacUM between atom IDs 56 and 50 with distance 6
# Reaction reacUA between atom IDs 72 and 80 with distance 8
# Reaction reacMU between atom IDs 73 and 67 with distance 6
# Reaction reacMU between atom IDs 49 and 70 with distance 21
# Reaction reacUM between atom IDs 21 and 17 with distance 4
# Reaction reacMU between atom IDs 47 and 42 with distance 5
# Reaction reacMU between atom IDs 45 and 37 with distance 8
# Reaction reacUM between atom IDs 65 and 61 with distance 4
# Reaction reacAU between atom IDs 74 and 69 with distance 5
# Reaction reacUA between atom IDs 71 and 75 with distance 4
# Reaction reacAU between atom IDs 14 and 10 with distance 4
# Reaction reacUA between atom IDs 31 and 27 with distance 4
# Reaction reacMU between atom IDs 49 and 45 with distance 4
# Reaction reacMU between atom IDs 43 and 38 with distance 5
# Reaction reacMU between atom IDs 48 and 56 with distance 8
# Reaction reacMU between atom IDs 25 and 29 with distance 4
# Reaction reacUM between atom IDs 26 and 35 with distance 9
# Reaction reacUM between atom IDs 72 and 78 with distance 6
# Reaction reacAU between atom IDs 73 and 78 with distance 5
# Reaction reacAU between atom IDs 48 and 52 with distance 4
# Reaction reacUM between atom IDs 39 and 43 with distance 4
# Reaction reacUM between atom IDs 11 and 16 with distance 5
# Reaction reacUA between atom IDs 17 and 23 with distance 6
# Reaction reacMU between atom IDs 5 and 10 with distance 5
# Reaction reacUM between atom IDs 28 and 24 with distance 4
# Reaction reacUA between atom IDs 3 and 7 with distance 4
# Reaction reacMU between atom IDs 65 and 69 with distance 4
# Reaction reacUA between atom IDs 43 and 49 with distance 6
# Reaction reacMU between atom IDs 19 and 4 with distance 15
# Reaction reacMU between atom IDs 65 and 59 with distance 6
# Reaction reacAU between atom IDs 58 and 68 with distance 10
# Reaction reacUA between atom IDs 63 and 58 with distance 5
# Reaction reacMU between atom IDs 40 and 36 with distance 4
# Reaction reacMU between atom IDs 4 and 8 with distance 4
# Reaction reacUM between atom IDs 46 and 28 with distance 18
# Reaction reacUM between atom IDs 5 and 10 with distance 5
# Reaction reacUM between atom IDs 28 and 13 with distance 15
# Reaction reacUM between atom IDs 41 and 34 with distance 7
# Reaction reacUM between atom IDs 29 and 33 with distance 4
# Reaction reacMU between atom IDs 73 and 78 with distance 5
# Reaction reacAU between atom IDs 73 and 69 with distance 4
# Reaction reacUA between atom IDs 11 and 16 with distance 5
# Reaction reacUM between atom IDs 31 and 35 with distance 4
# Reaction reacUA between atom IDs 21 and 26 with distance 5
# Reaction reacUM between atom IDs 18 and 32 with distance 14
# Reaction reacAU between atom IDs 59 and 55 with distance 4
# Reaction reacMU between atom IDs 50 and 54 with distance 4
# Reaction reacUA between atom IDs 41 and 30 with distance 11
# Reaction reacMU between atom IDs 40 and 44 with distance 4
# Reaction reacUA between atom IDs 11 and 15 with distance 4
# Reaction reacUM between atom IDs 11 and 15 with distance 4
# Reaction reacUM between atom IDs 18 and 26 with distance 8
# Reaction reacUA between atom IDs 32 and 28 with distance 4
# Reaction reacUA between atom IDs 35 and 48 with distance 13
# Reaction reacAU between atom IDs 21 and 25 with distance 4
# Reaction reacUM between atom IDs 49 and 45 with distance 4
# Reaction reacMU between atom IDs 51 and 55 with distance 4
# Reaction reacAU between atom IDs 17 and 26 with distance 9
# Reaction reacUM between atom IDs 52 and 14 with distance 38
# Reaction reacMU between atom IDs 17 and 48 with distance 31
# Reaction reacMU between atom IDs 54 and 1 with distance 53
# Reaction reacMU between atom IDs 51 and 10 with distance 41
# Reaction reacAU between atom IDs 50 and 7 with distance 43
# Reaction reacUM between atom IDs 18 and 23 with distance 5
# Reaction reacUA between atom IDs 14 and 10 with distance 4
# Reaction reacUM between atom IDs 12 and 16 with distance 4
# Reaction reacMU between atom IDs 41 and 37 with distance 4
# Reaction reacUA between atom IDs 75 and 71 with distance 4
# Reaction reacUM between atom IDs 39 and 34 with distance 5
# Reaction reacAU between atom IDs 38 and 34 with distance 4
# Reaction reacMU between atom IDs 61 and 66 with distance 5
# Reaction reacUA between atom IDs 24 and 28 with distance 4
# Reaction reacUA between atom IDs 56 and 50 with distance 6
# Reaction reacMU between atom IDs 30 and 26 with distance 4
# Reaction reacAU between atom IDs 20 and 15 with distance 5
# Reaction reacUA between atom IDs 34 and 30 with distance 4
# Reaction reacMU between atom IDs 76 and 80 with distance 4
# Reaction reacUM between atom IDs 67 and 73 with distance 6
# Reaction reacAU between atom IDs 46 and 39 with distance 7
# Reaction reacUM between atom IDs 18 and 7 with distance 11
# Reaction reacUM between atom IDs 5 and 25 with distance 20
# Reaction reacUM between atom IDs 3 and 15 with distance 12
# Reaction reacAU between atom IDs 47 and 43 with distance 4
# Reaction reacUM between atom IDs 72 and 68 with distance 4
# Reaction reacUM between atom IDs 7 and 11 with distance 4
# Reaction reacAU between atom IDs 22 and 18 with distance 4
# Reaction reacMU between atom IDs 46 and 50 with distance 4
# Reaction reacUM between atom IDs 16 and 3 with distance 13
# Reaction reacAU between atom IDs 59 and 50 with distance 9
# Reaction reacUM between atom IDs 66 and 62 with distance 4
# Reaction reacUA between atom IDs 44 and 40 with distance 4
# Reaction reacAU between atom IDs 5 and 9 with distance 4
# Reaction reacUA between atom IDs 58 and 52 with distance 6
# Reaction reacUM between atom IDs 33 and 37 with distance 4
# Reaction reacAU between atom IDs 72 and 68 with distance 4
# Reaction reacUM between atom IDs 24 and 20 with distance 4
# Reaction reacUA between atom IDs 6 and 14 with distance 8
# Reaction reacUA between atom IDs 10 and 5 with distance 5
# Reaction reacUA between atom IDs 13 and 3 with distance 10
# Reaction reacMU between atom IDs 34 and 30 with distance 4
# Reaction reacUM between atom IDs 27 and 32 with distance 5
# Reaction reacUA between atom IDs 25 and 18 with distance 7
# Reaction reacUM between atom IDs 25 and 29 with distance 4
# Reaction reacMU between atom IDs 9 and 5 with distance 4
# Reaction reacMU between atom IDs 36 and 18 with distance 18
# Reaction reacUA between atom IDs 33 and 22 with distance 11
# Reaction reacAU between atom IDs 16 and 20 with distance 4
# Reaction reacMU between atom IDs 79 and 75 with distance 4
# Reaction reacAU between atom IDs 61 and 25 with distance 36
# Reaction reacUM between atom IDs 64 and 68 with distance 4
# Reaction reacUM between atom IDs 17 and 22 with distance 5
# Reaction reacMU between atom IDs 25 and 21 with distance 4
# Reaction reacMU between atom IDs 23 and 35 with distance 12
# Reaction reacUA between atom IDs 36 and 26 with distance 10
# Reaction reacUM between atom IDs 41 and 46 with distance 5
# Reaction reacMU between atom IDs 49 and 54 with distance 5
# Reaction reacAU between atom IDs 52 and 58 with distance 6
# Reaction reacUA between atom IDs 41 and 45 with distance 4
# Reaction reacUA between atom IDs 57 and 61 with distance 4
# Reaction reacAU between atom IDs 78 and 74 with distance 4
# Reaction reacUM between atom IDs 46 and 42 with distance 4
# Reaction reacMU between atom IDs 73 and 77 with distance 4
# Reaction reacMU between atom IDs 68 and 72 with distance 4
# Reaction reacMU between atom IDs 52 and 48 with distance 4
# Reaction reacUA between atom IDs 76 and 69 with distance 7
# Reaction reacUM between atom IDs 62 and 56 with distance 6
# Reaction reacUA between atom IDs 6 and 2 with distance 4
# Reaction reacUA between atom IDs 32 and 27 with distance 5
# Reaction reacMU between atom IDs 5 and 11 with distance 6
# Reaction reacUA between atom IDs 33 and 41 with distance 8
# Reaction reacUM between atom IDs 33 and 29 with distance 4
# Reaction reacUM between atom IDs 65 and 69 with distance 4
# Reaction reacMU between atom IDs 78 and 74 with distance 4
# Reaction reacAU between atom IDs 79 and 69 with distance 10
# Reaction reacUM between atom IDs 9 and 21 with distance 12
# Reaction reacUM between atom IDs 9 and 23 with distance 14
# Reaction reacMU between atom IDs 47 and 37 with distance 10
# Reaction reacUA between atom IDs 76 and 80 with distance 4
# Reaction reacAU between atom IDs 52 and 40 with distance 12
# Reaction reacMU between atom IDs 16 and 12 with distance 4
# Reaction reacMU between atom IDs 36 and 41 with distance 5
# Reaction reacMU between atom IDs 53 and 57 with distance 4
# Reaction reacUM between atom IDs 9 and 15 with distance 6
# Reaction reacUM between atom IDs 42 and 38 with distance 4
# Reaction reacUA between atom IDs 32 and 36 with distance 4
# Reaction reacUA between atom IDs 76 and 57 with distance 19
# Reaction reacAU between atom IDs 74 and 59 with distance 15
# Reaction reacUM between atom IDs 18 and 14 with distance 4
# Reaction reacUM between atom IDs 32 and 37 with distance 5
# Reaction reacAU between atom IDs 35 and 29 with distance 6
# Reaction reacMU between atom IDs 73 and 69 with distance 4
# Reaction reacMU between atom IDs 72 and 68 with distance 4
# Reaction reacAU between atom IDs 56 and 52 with distance 4
# Reaction reacAU between atom IDs 55 and 61 with distance 6
# Reaction reacAU between atom IDs 11 and 15 with distance 4
# Reaction reacUM between atom IDs 76 and 80 with distance 4
# Reaction reacMU between atom IDs 64 and 60 with distance 4
# Reaction reacMU between atom IDs 15 and 10 with distance 5
# Reaction reacUA between atom IDs 69 and 73 with distance 4
# Reaction reacUM between atom IDs 20 and 24 with distance 4
# Reaction reacAU between atom IDs 66 and 70 with distance 4
# Reaction reacUM between atom IDs 57 and 52 with distance 5
# Reaction reacUA between atom IDs 20 and 16 with distance 4
# Reaction reacUA between atom IDs 33 and 29 with distance 4
# Reaction reacUA between atom IDs 28 and 19 with distance 9
# Reaction reacMU between atom IDs 40 and 35 with distance 5
# Reaction reacUA between atom IDs 48 and 44 with distance 4
# Reaction reacUA between atom IDs 13 and 1 with distance 12
# Reaction reacUM between atom IDs 17 and 30 with distance 13
# Reaction reacAU between atom IDs 21 and 33 with distance 12
# Reaction reacUA between atom IDs 17 and 27 with distance 10
# Reaction reacUM between atom IDs 10 and 27 with distance 17
# Reaction reacUA between atom IDs 23 and 10 with distance 13
# Reaction reacAU between atom IDs 15 and 20 with distance 5
# Reaction reacAU between atom IDs 8 and 36 with distance 28
# Reaction reacMU between atom IDs 32 and 14 with distance 18
# Reaction reacMU between atom IDs 11 and 15 with distance 4
# Reaction reacMU between atom IDs 32 and 28 with distance 4
# Reaction reacUM between atom IDs 80 and 76 with distance 4
# Reaction reacUM between atom IDs 17 and 21 with distance 4
# Reaction reacUA between atom IDs 30 and 35 with distance 5
# Reaction reacAU between atom IDs 7 and 45 with distance 38
# Reaction reacMU between atom IDs 18 and 23 with distance 5
# Reaction reacMU between atom IDs 49 and 57 with distance 8
# Reaction reacAU between atom IDs 56 and 51 with distance 5
# Reaction reacUA between atom IDs 30 and 22 with distance 8
# Reaction reacMU between atom IDs 58 and 66 with distance 8
# Reaction reacAU between atom IDs 66 and 80 with distance 14
# Reaction reacMU between atom IDs 12 and 7 with distance 5
# Reaction reacUM between atom IDs 44 and 38 with distance 6
# Reaction reacUA between atom IDs 57 and 53 with distance 4
# Reaction reacMU between atom IDs 59 and 51 with distance 8
# Reaction reacUM between atom IDs 67 and 71 with distance 4
# Reaction reacAU between atom IDs 46 and 52 with distance 6
# Reaction reacUM between atom IDs 71 and 75 with distance 4
# Reaction reacUM between atom IDs 10 and 6 with distance 4
# Reaction reacUM between atom IDs 61 and 66 with distance 5
# Reaction reacUA between atom IDs 5 and 14 with distance 9
# Reaction reacMU between atom IDs 49 and 53 with distance 4
# Reaction reacAU between atom IDs 8 and 1 with distance 7
# Reaction reacAU between atom IDs 73 and 67 with distance 6
# Reaction reacMU between atom IDs 29 and 34 with distance 5
# Reaction reacUM between atom IDs 56 and 52 with distance 4
# Reaction reacAU between atom IDs 60 and 56 with distance 4
# Reaction reacUA between atom IDs 44 and 39 with distance 5
# Reaction reacUM between atom IDs 21 and 27 with distance 6
# Reaction reacUM between atom IDs 38 and 48 with distance 10
# Reaction reacMU between atom IDs 71 and 75 with distance 4
# Reaction reacUM between atom IDs 21 and 42 with distance 21
# Reaction reacUA between atom IDs 27 and 31 with distance 4
# Reaction reacAU between atom IDs 50 and 44 with distance 6
# Reaction reacMU between atom IDs 34 and 45 with distance 11
# Reaction reacAU between atom IDs 73 and 77 with distance 4
# Reaction reacMU between atom IDs 49 and 44 with distance 5
# Reaction reacAU between atom IDs 57 and 63 with distance 6
# Reaction reacAU between atom IDs 10 and 6 with distance 4
# Reaction reacUA between atom IDs 62 and 58 with distance 4
# Reaction reacAU between atom IDs 44 and 48 with distance 4
# Reaction reacUM between atom IDs 7 and 80 with distance 73
# Reaction reacAU between atom IDs 57 and 45 with distance 12
# Reaction reacAU between atom IDs 34 and 52 with distance 18
# Reaction reacAU between atom IDs 69 and 57 with distance 12
# Reaction reacUM between atom IDs 40 and 11 with distance 29
# Reaction reacMU between atom IDs 68 and 63 with distance 5
# Reaction reacAU between atom IDs 3 and 25 with distance 22
# Reaction reacUM between atom IDs 26 and 2 with distance 24
# Reaction reacAU between atom IDs 75 and 71 with distance 4
# Reaction reacUA between atom IDs 5 and 63 with distance 58
# Reaction reacAU between atom IDs 10 and 61 with distance 51
# Reaction reacUM between atom IDs 60 and 1 with distance 59
# Reaction reacAU between atom IDs 70 and 66 with distance 4
# Reaction reacMU between atom IDs 10 and 6 with distance 4
# Reaction reacUM between atom IDs 78 and 67 with distance 11
# Reaction reacUA between atom IDs 7 and 3 with distance 4
# Reaction reacAU between atom IDs 55 and 33 with distance 22
# Reaction reacUA between atom IDs 26 and 22 with distance 4
# Reaction reacAU between atom IDs 67 and 62 with distance 5
# Reaction reacMU between atom IDs 43 and 47 with distance 4
# Reaction reacAU between atom IDs 34 and 30 with distance 4
# Reaction reacUA between atom IDs 64 and 56 with distance 8
# Reaction reacUA between atom IDs 80 and 75 with distance 5
# Reaction reacUA between atom IDs 50 and 43 with distance 7
# Reaction reacUA between atom IDs 60 and 55 with distance 5
# Reaction reacUM between atom IDs 61 and 55 with distance 6
# Reaction reacUA between atom IDs 61 and 56 with distance 5
# Reaction reacAU between atom IDs 42 and 47 with distance 5
# Reaction reacUM between atom IDs 30 and 25 with distance 5
# Reaction reacUA between atom IDs 10 and 14 with distance 4
# Reaction reacAU between atom IDs 59 and 68 with distance 9
# Reaction reacUM between atom IDs 62 and 80 with distance 18
# Reaction reacUA between atom IDs 55 and 59 with distance 4
# Reaction reacUA between atom IDs 11 and 1 with distance 10
# Reaction reacAU between atom IDs 67 and 63 with distance 4
# Reaction reacAU between atom IDs 23 and 28 with distance 5
# Reaction reacMU between atom IDs 32 and 36 with distance 4
# Reaction reacUM between atom IDs 3 and 7 with distance 4
# Reaction reacMU between atom IDs 5 and 1 with distance 4
# Reaction reacUA between atom IDs 43 and 37 with distance 6
# Reaction reacAU between atom IDs 65 and 69 with distance 4
# Reaction reacUM between atom IDs 22 and 18 with distance 4
# Reaction reacUA between atom IDs 80 and 76 with distance 4
# Reaction reacUA between atom IDs 2 and 6 with distance 4
# Reaction reacMU between atom IDs 22 and 17 with distance 5
# Reaction reacMU between atom IDs 71 and 78 with distance 7
# Reaction reacMU between atom IDs 17 and 21 with distance 4
# Reaction reacUM between atom IDs 24 and 28 with distance 4
# Reaction reacUA between atom IDs 63 and 67 with distance 4
# Reaction reacUM between atom IDs 66 and 54 with distance 12
# Reaction reacAU between atom IDs 43 and 47 with distance 4
# Reaction reacUM between atom IDs 51 and 47 with distance 4
# Reaction reacMU between atom IDs 70 and 75 with distance 5
# Reaction reacMU between atom IDs 10 and 15 with distance 5
# Reaction reacUA between atom IDs 68 and 74 with distance 6
# Reaction reacMU between atom IDs 26 and 30 with distance 4
# Reaction reacUM between atom IDs 47 and 51 with distance 4
# Reaction reacUM between atom IDs 64 and 60 with distance 4
# Reaction reacUA between atom IDs 79 and 75 with distance 4
# Reaction reacMU between atom IDs 38 and 34 with distance 4
# Reaction reacUM between atom IDs 33 and 18 with distance 15
# Reaction reacUM between atom IDs 11 and 4 with distance 7
# Reaction reacUM between atom IDs 30 and 36 with distance 6
# Reaction reacAU between atom IDs 41 and 37 with distance 4
# Reaction reacUA between atom IDs 11 and 5 with distance 6
# Reaction reacMU between atom IDs 62 and 56 with distance 6
# Reaction reacAU between atom IDs 48 and 33 with distance 15
# Reaction reacMU between atom IDs 44 and 36 with distance 8
# Reaction reacUA between atom IDs 53 and 26 with distance 27
# Reaction reacMU between atom IDs 62 and 58 with distance 4
# Reaction reacMU between atom IDs 38 and 33 with distance 5
# Reaction reacUA between atom IDs 34 and 39 with distance 5
# Reaction reacMU between atom IDs 35 and 39 with distance 4
# Reaction reacAU between atom IDs 56 and 60 with distance 4
# Reaction reacUM between atom IDs 30 and 26 with distance 4
# Reaction reacAU between atom IDs 19 and 9 with distance 10
# Reaction reacUM between atom IDs 2 and 47 with distance 45
# Reaction reacAU between atom IDs 35 and 30 with distance 5
# Reaction reacUA between atom IDs 1 and 51 with distance 50
# Reaction reacAU between atom IDs 8 and 4 with distance 4
# Reaction reacMU between atom IDs 13 and 77 with distance 64
# Reaction reacAU between atom IDs 42 and 34 with distance 8
# Reaction reacMU between atom IDs 33 and 37 with distance 4
# Reaction reacAU between atom IDs 12 and 16 with distance 4
# Reaction reacUA between atom IDs 72 and 41 with distance 31
# Reaction reacUM between atom IDs 44 and 48 with distance 4
# Reaction reacUM between atom IDs 55 and 74 with distance 19
# Reaction reacUM between atom IDs 74 and 54 with distance 20
# Reaction reacMU between atom IDs 56 and 76 with distance 20
# Reaction reacAU between atom IDs 69 and 49 with distance 20
# Reaction reacUM between atom IDs 53 and 47 with distance 6
# Reaction reacUA between atom IDs 65 and 61 with distance 4
# Reaction reacAU between atom IDs 7 and 80 with distance 73
# Reaction reacUM between atom IDs 47 and 41 with distance 6
# Reaction reacAU between atom IDs 38 and 45 with distance 7
# Reaction reacAU between atom IDs 69 and 63 with distance 6

# %%
import re
import matplotlib.pyplot as plt

# Define the path to your log file
log_file_path = 'output.log'

# Initialize dictionaries to store counts and distances for each type of reaction
reaction_counts = {'f1': 0, 'f2': 0, 'f3': 0, 'f4': 0}
reaction_distances = {'f1': set(), 'f2': set(), 'f3': set(), 'f4': set()}

# Define a mapping from log reaction types to our reaction types
reaction_map = {'reacAU': 'f1', 'reacMU': 'f2', 'reacUA': 'f3', 'reacUM': 'f4'}

# Define a regex pattern to match lines containing reacting atom IDs and reaction types
pattern = re.compile(r'reacted_atom_IDs: (reac\w+) (\d+) (\d+)')

# Open the log file and read its contents
with open(log_file_path, 'r') as file:
    lines = file.readlines()

# Loop through each line and search for the pattern
for line in lines:
    match = pattern.search(line)
    if match:
        # Extract the reaction type and atom IDs
        reaction_type = match.group(1)
        atom_id_1 = int(match.group(2))
        atom_id_2 = int(match.group(3))
        
        # Calculate distance
        distance = abs(atom_id_1 - atom_id_2)
        
        # Get the corresponding reaction type from the map
        reaction_key = reaction_map[reaction_type]
        
        # Check if this reaction data already exists
        if (atom_id_1, atom_id_2, distance) not in reaction_distances[reaction_key]:
            # Append distance to the appropriate reaction type
            reaction_distances[reaction_key].add((atom_id_1, atom_id_2, distance))
            
            # Increment the count for the corresponding reaction type
            reaction_counts[reaction_key] += 1

labels = {'f1': 'Reaction A to U', 'f2': 'Reaction M to U', 'f3': 'Reaction U to A', 'f4': 'Reaction U to M'}

# Plot histograms of distances for each reaction type
plt.figure(figsize=(12, 8))
for reaction_type, distances in reaction_distances.items():
    plt.hist([distance[2] for distance in distances], bins=20, alpha=0.7, label=f'{labels[reaction_type]}', density=True)

plt.title('Histogram of Distances for Each Reaction Type')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# Print the counts of each reaction type
for reaction_type, count in reaction_counts.items():
    print(f'{labels[reaction_type]} count: {count}')
# Out:
# Reaction A to U count: 152
# Reaction M to U count: 158
# Reaction U to A count: 165
# Reaction U to M count: 188

# %%
import re
import matplotlib.pyplot as plt

# Define the path to your log file
log_file_path = 'output.log'

# Initialize dictionaries to store counts and distances for each type of reaction
reaction_counts = {'f1': 0, 'f2': 0, 'f3': 0, 'f4': 0}
reaction_distances = {'f1': set(), 'f2': set(), 'f3': set(), 'f4': set()}

# Define a mapping from log reaction types to our reaction types
reaction_map = {'reacAU': 'f1', 'reacMU': 'f2', 'reacUA': 'f3', 'reacUM': 'f4'}

# Define a regex pattern to match lines containing reacting atom IDs and reaction types
pattern = re.compile(r'reacted_atom_IDs: (reac\w+) (\d+) (\d+)')

# Open the log file and read its contents
with open(log_file_path, 'r') as file:
    lines = file.readlines()

# Loop through each line and search for the pattern
for line in lines:
    match = pattern.search(line)
    if match:
        # Extract the reaction type and atom IDs
        reaction_type = match.group(1)
        atom_id_1 = int(match.group(2))
        atom_id_2 = int(match.group(3))
        
        # Calculate distance
        distance = abs(atom_id_1 - atom_id_2)
        
        # Get the corresponding reaction type from the map
        reaction_key = reaction_map[reaction_type]
        
        # Add the reaction event to the set of unique events
        reaction_distances[reaction_key].add((reaction_type, atom_id_1, atom_id_2))
        
        # Increment the count for the corresponding reaction type
        reaction_counts[reaction_key] += 1

labels = {'f1': 'Reaction A to U', 'f2': 'Reaction M to U', 'f3': 'Reaction U to A', 'f4': 'Reaction U to M'}

# Plot histograms of distances for each reaction type
plt.figure(figsize=(12, 8))
for reaction_type, distances in reaction_distances.items():
    plt.hist([abs(id1 - id2) for _, id1, id2 in distances], bins=20, alpha=0.7, label=f'{labels[reaction_type]}', density=True)

plt.title('Histogram of Distances for Each Reaction Type')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# Print the counts of each reaction type
for reaction_type, count in reaction_counts.items():
    print(f'{labels[reaction_type]} count: {count}')
# Out:
# Reaction A to U count: 178
# Reaction M to U count: 185
# Reaction U to A count: 186
# Reaction U to M count: 220

# %%
import re
import matplotlib.pyplot as plt

# Define the path to your log file
log_file_path = 'output.log'

# Initialize dictionaries to store counts and distances for each type of reaction
reaction_counts = {'f1': 0, 'f2': 0, 'f3': 0, 'f4': 0}
reaction_distances = {'f1': [], 'f2': [], 'f3': [], 'f4': []}

# Define a mapping from log reaction types to our reaction types
reaction_map = {'reacAU': 'f1', 'reacMU': 'f2', 'reacUA': 'f3', 'reacUM': 'f4'}

# Define a regex pattern to match lines containing reacting atom IDs and reaction types
pattern = re.compile(r'reacted_atom_IDs: (reac\w+) (\d+) (\d+)')

# Open the log file and read its contents
with open(log_file_path, 'r') as file:
    lines = file.readlines()

# Loop through each line and search for the pattern
for line in lines:
    match = pattern.search(line)
    if match:
        # Extract the reaction type and atom IDs
        reaction_type = match.group(1)
        atom_id_1 = int(match.group(2))
        atom_id_2 = int(match.group(3))
        
        # Calculate distance
        distance = abs(atom_id_1 - atom_id_2)
        
        # Get the corresponding reaction type from the map
        reaction_key = reaction_map[reaction_type]
        
        # Add the reaction event to the list of distances
        reaction_distances[reaction_key].append(distance)
        
        # Increment the count for the corresponding reaction type
        reaction_counts[reaction_key] += 1

labels = {'f1': 'Reaction A to U', 'f2': 'Reaction M to U', 'f3': 'Reaction U to A', 'f4': 'Reaction U to M'}
colors = {'f1': 'yellow', 'f2': 'gold', 'f3': 'blue', 'f4': 'red'}

# Plot histograms of distances for each reaction type in subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Histograms of Distances for Each Reaction Type')

for ax, (reaction_type, distances) in zip(axs.flatten(), reaction_distances.items()):
    ax.hist(distances, bins=20, alpha=0.7, density=True, color=colors[reaction_type])
    ax.set_title(labels[reaction_type])
    ax.set_xlabel('Distance')
    ax.set_ylabel('Frequency')
    ax.grid(True)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# Print the counts of each reaction type
for reaction_type, count in reaction_counts.items():
    print(f'{labels[reaction_type]} count: {count}')
# Out:
# Reaction A to U count: 178
# Reaction M to U count: 185
# Reaction U to A count: 186
# Reaction U to M count: 220

# %%
import re
import matplotlib.pyplot as plt

# Define the path to your log file
log_file_path = 'output.log'

# Initialize dictionaries to store counts and distances for each type of reaction
reaction_counts = {'f1': 0, 'f2': 0, 'f3': 0, 'f4': 0}
reaction_distances = {'f1': [], 'f2': [], 'f3': [], 'f4': []}

# Define a mapping from log reaction types to our reaction types
reaction_map = {'reacAU': 'f1', 'reacMU': 'f2', 'reacUA': 'f3', 'reacUM': 'f4'}

# Define a regex pattern to match lines containing reacting atom IDs and reaction types
pattern = re.compile(r'reacted_atom_IDs: (reac\w+) (\d+) (\d+)')

# Open the log file and read its contents
with open(log_file_path, 'r') as file:
    lines = file.readlines()

# Loop through each line and search for the pattern
for line in lines:
    match = pattern.search(line)
    if match:
        # Extract the reaction type and atom IDs
        reaction_type = match.group(1)
        atom_id_1 = int(match.group(2))
        atom_id_2 = int(match.group(3))
        
        # Calculate distance
        distance = abs(atom_id_1 - atom_id_2)
        
        # Get the corresponding reaction type from the map
        reaction_key = reaction_map[reaction_type]
        
        # Add the reaction event to the list of distances
        reaction_distances[reaction_key].append(distance)
        
        # Increment the count for the corresponding reaction type
        reaction_counts[reaction_key] += 1

labels = {'f1': 'Reaction A to U', 'f2': 'Reaction M to U', 'f3': 'Reaction U to A', 'f4': 'Reaction U to M'}
colors = {'f1': 'yellow', 'f2': 'gold', 'f3': 'blue', 'f4': 'red'}

# Plot histograms of distances for each reaction type in subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Histograms of Distances for Each Reaction Type')

for ax, (reaction_type, distances) in zip(axs.flatten(), reaction_distances.items()):
    ax.hist(distances, bins=20, alpha=0.7, density=True, color=colors[reaction_type])
    ax.set_title(labels[reaction_type])
    ax.set_xlabel('Distance')
    ax.set_ylabel('Frequency')
    ax.grid(True)
    ax.set_yscale('log')
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# Print the counts of each reaction type
for reaction_type, count in reaction_counts.items():
    print(f'{labels[reaction_type]} count: {count}')
# Out:
# Reaction A to U count: 178
# Reaction M to U count: 185
# Reaction U to A count: 186
# Reaction U to M count: 220

# %%
A = np.linspace(50,5000,50)

# %%
for j in A:
    print(int(j),end = " ")
# Out:
# 50 151 252 353 454 555 656 757 858 959 1060 1161 1262 1363 1464 1565 1666 1767 1868 1969 2070 2171 2272 2373 2474 2575 2676 2777 2878 2979 3080 3181 3282 3383 3484 3585 3686 3787 3888 3989 4090 4191 4292 4393 4494 4595 4696 4797 4898 5000
