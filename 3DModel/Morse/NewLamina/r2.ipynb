# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the .dat file into a pandas DataFrame
df = pd.read_csv('r2.dat', comment='#', delim_whitespace=True, names=['TimeStep', 'R_g'])

# Plot c_R2[0] against TimeStep
plt.plot(df['TimeStep'], df['R_g'])
plt.xlabel('TimeStep')
plt.ylabel('$R_g$')
plt.title('Plot of $R_g$ of all A vs TimeStep')
plt.grid(True)
plt.show()
# Out:
# /var/folders/jg/gqqb9c4s6qd3ftqhm6____m80000gn/T/ipykernel_2601/4213715770.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('r2.dat', comment='#', delim_whitespace=True, names=['TimeStep', 'R_g'])
