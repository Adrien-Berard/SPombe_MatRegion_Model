# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import re

# %%
import re
import matplotlib.pyplot as plt

# Define the path to your log file
log_file_path = 'output.log'

# Initialize a dictionary to store the count of each reaction type
reaction_counts = {
    'f1': 0,
    'f2': 0,
    'f3': 0,
    'f4': 0
}

# Initialize dictionaries to store distances for each type of reaction
reaction_distances = {
    'f1': [],
    'f2': [],
    'f3': [],
    'f4': []
}

# Define a mapping from log reaction types to our reaction types
reaction_map = {
    'reacUM': 'f1',
    'reacMU': 'f2',
    'reacUA': 'f3',
    'reacAU': 'f4'
}

# Open the log file and read its contents
with open(log_file_path, 'r') as file:
    lines = file.readlines()

# Define a regex pattern to match lines containing reacting atom IDs and reaction types
pattern = re.compile(r'reacted_atom_IDs: (reac\w+) (\d+) (\d+)')

# Loop through each line and search for the pattern
for line in lines:
    match = pattern.search(line)
    if match:
        # Extract the reaction type and atom IDs
        reaction_type = match.group(1)
        atom_id_1 = int(match.group(2))
        atom_id_2 = int(match.group(3))
        
        # Calculate distance
        distance = abs(atom_id_1 - atom_id_2)
        
        # Get the corresponding reaction type from the map
        reaction_key = reaction_map[reaction_type]
        
        # Append distance to the appropriate reaction type
        reaction_distances[reaction_key].append(distance)
        
        # Increment the count for the corresponding reaction type
        reaction_counts[reaction_key] += 1

labels = {
    'f1': 'Reaction A to U',
    'f2': 'Reaction M to U',
    'f3': 'Reaction U to A',
    'f4': 'Reaction U to U'
}

# Plot histograms of distances for each reaction type
plt.figure(figsize=(12, 8))
for reaction_type, distances in reaction_distances.items():
    plt.hist(distances, bins=20, alpha=0.7, label=f'{labels[reaction_type]}', density=False)

plt.title('Histogram of Distances for Each Reaction Type')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# Print the counts of each reaction type
for reaction_type, count in reaction_counts.items():
    print(f'{labels[reaction_type]} count: {count}')
# Out:
# Reaction A to U count: 23
# Reaction M to U count: 21
# Reaction U to A count: 22
# Reaction U to U count: 22

# %%
import re
import matplotlib.pyplot as plt

# Define the path to your log file
log_file_path = 'output.log'

# Initialize a dictionary to store the count of each reaction type
reaction_counts = {
    'f1': 0,
    'f2': 0,
    'f3': 0,
    'f4': 0
}

# Initialize dictionaries to store distances for each type of reaction
reaction_distances = {
    'f1': [],
    'f2': [],
    'f3': [],
    'f4': []
}

# Define a mapping from log reaction types to our reaction types
reaction_map = {
    'reacAU': 'f1',
    'reacMU': 'f2',
    'reacUA': 'f3',
    'reacUM': 'f4'
}

# Open the log file and read its contents
with open(log_file_path, 'r') as file:
    lines = file.readlines()

# Define a regex pattern to match lines containing reacting atom IDs and reaction types
pattern = re.compile(r'reacted_atom_IDs: (reac\w+) (\d+) (\d+)')

# List to store reaction data for further use if needed
reaction_data = []

# Loop through each line and search for the pattern
for line in lines:
    match = pattern.search(line)
    if match:
        # Extract the reaction type and atom IDs
        reaction_type = match.group(1)
        atom_id_1 = int(match.group(2))
        atom_id_2 = int(match.group(3))
        
        # Calculate distance
        distance = abs(atom_id_1 - atom_id_2)
        
        # Get the corresponding reaction type from the map
        reaction_key = reaction_map[reaction_type]
        
        # Check if this reaction data already exists
        if (reaction_type, atom_id_1, atom_id_2, distance) not in reaction_data:
            # Append distance to the appropriate reaction type
            reaction_distances[reaction_key].append(distance)
            
            # Increment the count for the corresponding reaction type
            reaction_counts[reaction_key] += 1
    
            # Store the reaction data (including reaction type)
            reaction_data.append((reaction_type, atom_id_1, atom_id_2, distance))


labels = {
    'f1': 'Reaction A to U',
    'f2': 'Reaction M to U',
    'f3': 'Reaction U to A',
    'f4': 'Reaction U to M'
}

# Plot histograms of distances for each reaction type
plt.figure(figsize=(12, 8))
for reaction_type, distances in reaction_distances.items():
    plt.hist(distances, bins=20, alpha=0.7, label=f'{labels[reaction_type]}', density=True)

plt.title('Histogram of Distances for Each Reaction Type')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# Print the counts of each reaction type
for reaction_type, count in reaction_counts.items():
    print(f'{labels[reaction_type]} count: {count}')

# Print stored reaction data if needed
for reaction in reaction_data:
    print(f'Reaction {reaction[0]} between atom IDs {reaction[1]} and {reaction[2]} with distance {reaction[3]}')
# Out:
# Reaction A to U count: 21
# Reaction M to U count: 19
# Reaction U to A count: 22
# Reaction U to M count: 21
# Reaction reacUM between atom IDs 16 and 2 with distance 14
# Reaction reacUM between atom IDs 5 and 13 with distance 8
# Reaction reacUM between atom IDs 15 and 3 with distance 12
# Reaction reacAU between atom IDs 18 and 1 with distance 17
# Reaction reacUM between atom IDs 3 and 16 with distance 13
# Reaction reacUM between atom IDs 14 and 6 with distance 8
# Reaction reacAU between atom IDs 2 and 15 with distance 13
# Reaction reacMU between atom IDs 11 and 7 with distance 4
# Reaction reacUA between atom IDs 4 and 15 with distance 11
# Reaction reacUA between atom IDs 14 and 7 with distance 7
# Reaction reacAU between atom IDs 2 and 14 with distance 12
# Reaction reacUM between atom IDs 6 and 12 with distance 6
# Reaction reacUA between atom IDs 138 and 128 with distance 10
# Reaction reacMU between atom IDs 2 and 15 with distance 13
# Reaction reacUA between atom IDs 3 and 18 with distance 15
# Reaction reacUA between atom IDs 126 and 140 with distance 14
# Reaction reacAU between atom IDs 2 and 17 with distance 15
# Reaction reacMU between atom IDs 121 and 137 with distance 16
# Reaction reacUA between atom IDs 124 and 137 with distance 13
# Reaction reacUA between atom IDs 4 and 16 with distance 12
# Reaction reacAU between atom IDs 130 and 145 with distance 15
# Reaction reacMU between atom IDs 2 and 8 with distance 6
# Reaction reacUA between atom IDs 120 and 139 with distance 19
# Reaction reacUA between atom IDs 141 and 123 with distance 18
# Reaction reacAU between atom IDs 121 and 140 with distance 19
# Reaction reacMU between atom IDs 121 and 140 with distance 19
# Reaction reacUM between atom IDs 124 and 145 with distance 21
# Reaction reacUA between atom IDs 5 and 15 with distance 10
# Reaction reacAU between atom IDs 9 and 20 with distance 11
# Reaction reacMU between atom IDs 142 and 136 with distance 6
# Reaction reacUA between atom IDs 3 and 13 with distance 10
# Reaction reacUA between atom IDs 5 and 11 with distance 6
# Reaction reacAU between atom IDs 149 and 131 with distance 18
# Reaction reacMU between atom IDs 149 and 131 with distance 18
# Reaction reacUA between atom IDs 124 and 142 with distance 18
# Reaction reacUM between atom IDs 21 and 11 with distance 10
# Reaction reacAU between atom IDs 151 and 129 with distance 22
# Reaction reacMU between atom IDs 2 and 18 with distance 16
# Reaction reacUM between atom IDs 139 and 130 with distance 9
# Reaction reacUM between atom IDs 141 and 128 with distance 13
# Reaction reacAU between atom IDs 18 and 4 with distance 14
# Reaction reacMU between atom IDs 131 and 150 with distance 19
# Reaction reacUA between atom IDs 144 and 137 with distance 7
# Reaction reacUA between atom IDs 128 and 140 with distance 12
# Reaction reacAU between atom IDs 9 and 5 with distance 4
# Reaction reacMU between atom IDs 147 and 123 with distance 24
# Reaction reacUA between atom IDs 143 and 125 with distance 18
# Reaction reacUM between atom IDs 28 and 9 with distance 19
# Reaction reacAU between atom IDs 149 and 145 with distance 4
# Reaction reacMU between atom IDs 136 and 146 with distance 10
# Reaction reacUM between atom IDs 138 and 147 with distance 9
# Reaction reacUM between atom IDs 11 and 25 with distance 14
# Reaction reacAU between atom IDs 123 and 144 with distance 21
# Reaction reacMU between atom IDs 146 and 140 with distance 6
# Reaction reacUM between atom IDs 3 and 14 with distance 11
# Reaction reacAU between atom IDs 148 and 135 with distance 13
# Reaction reacMU between atom IDs 7 and 27 with distance 20
# Reaction reacUM between atom IDs 138 and 146 with distance 8
# Reaction reacAU between atom IDs 133 and 137 with distance 4
# Reaction reacMU between atom IDs 155 and 129 with distance 26
# Reaction reacUM between atom IDs 28 and 7 with distance 21
# Reaction reacUM between atom IDs 119 and 145 with distance 26
# Reaction reacAU between atom IDs 140 and 128 with distance 12
# Reaction reacMU between atom IDs 148 and 144 with distance 4
# Reaction reacUA between atom IDs 130 and 159 with distance 29
# Reaction reacUA between atom IDs 25 and 7 with distance 18
# Reaction reacAU between atom IDs 133 and 125 with distance 8
# Reaction reacMU between atom IDs 10 and 30 with distance 20
# Reaction reacUA between atom IDs 16 and 22 with distance 6
# Reaction reacUA between atom IDs 120 and 135 with distance 15
# Reaction reacAU between atom IDs 131 and 143 with distance 12
# Reaction reacMU between atom IDs 18 and 5 with distance 13
# Reaction reacUA between atom IDs 141 and 137 with distance 4
# Reaction reacUA between atom IDs 132 and 150 with distance 18
# Reaction reacAU between atom IDs 136 and 145 with distance 9
# Reaction reacUM between atom IDs 28 and 8 with distance 20
# Reaction reacUM between atom IDs 21 and 2 with distance 19
# Reaction reacAU between atom IDs 150 and 130 with distance 20
# Reaction reacMU between atom IDs 133 and 146 with distance 13
# Reaction reacUM between atom IDs 137 and 142 with distance 5
# Reaction reacUM between atom IDs 14 and 23 with distance 9
# Reaction reacAU between atom IDs 155 and 142 with distance 13
# Reaction reacMU between atom IDs 133 and 145 with distance 12

# %%
import re
import matplotlib.pyplot as plt

# Define the path to your log file
log_file_path = 'output.log'

# Initialize dictionaries to store counts and distances for each type of reaction
reaction_counts = {'f1': 0, 'f2': 0, 'f3': 0, 'f4': 0}
reaction_distances = {'f1': set(), 'f2': set(), 'f3': set(), 'f4': set()}

# Define a mapping from log reaction types to our reaction types
reaction_map = {'reacAU': 'f1', 'reacMU': 'f2', 'reacUA': 'f3', 'reacUM': 'f4'}

# Define a regex pattern to match lines containing reacting atom IDs and reaction types
pattern = re.compile(r'reacted_atom_IDs: (reac\w+) (\d+) (\d+)')

# Open the log file and read its contents
with open(log_file_path, 'r') as file:
    lines = file.readlines()

# Loop through each line and search for the pattern
for line in lines:
    match = pattern.search(line)
    if match:
        # Extract the reaction type and atom IDs
        reaction_type = match.group(1)
        atom_id_1 = int(match.group(2))
        atom_id_2 = int(match.group(3))
        
        # Calculate distance
        distance = abs(atom_id_1 - atom_id_2)
        
        # Get the corresponding reaction type from the map
        reaction_key = reaction_map[reaction_type]
        
        # Check if this reaction data already exists
        if (atom_id_1, atom_id_2, distance) not in reaction_distances[reaction_key]:
            # Append distance to the appropriate reaction type
            reaction_distances[reaction_key].add((atom_id_1, atom_id_2, distance))
            
            # Increment the count for the corresponding reaction type
            reaction_counts[reaction_key] += 1

labels = {'f1': 'Reaction A to U', 'f2': 'Reaction M to U', 'f3': 'Reaction U to A', 'f4': 'Reaction U to M'}

# Plot histograms of distances for each reaction type
plt.figure(figsize=(12, 8))
for reaction_type, distances in reaction_distances.items():
    plt.hist([distance[2] for distance in distances], bins=20, alpha=0.7, label=f'{labels[reaction_type]}', density=True)

plt.title('Histogram of Distances for Each Reaction Type')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# Print the counts of each reaction type
for reaction_type, count in reaction_counts.items():
    print(f'{labels[reaction_type]} count: {count}')
# Out:
# Reaction A to U count: 21
# Reaction M to U count: 19
# Reaction U to A count: 22
# Reaction U to M count: 21

# %%
import re
import matplotlib.pyplot as plt

# Define the path to your log file
log_file_path = 'output.log'

# Initialize dictionaries to store counts and distances for each type of reaction
reaction_counts = {'f1': 0, 'f2': 0, 'f3': 0, 'f4': 0}
reaction_distances = {'f1': set(), 'f2': set(), 'f3': set(), 'f4': set()}

# Define a mapping from log reaction types to our reaction types
reaction_map = {'reacAU': 'f1', 'reacMU': 'f2', 'reacUA': 'f3', 'reacUM': 'f4'}

# Define a regex pattern to match lines containing reacting atom IDs and reaction types
pattern = re.compile(r'reacted_atom_IDs: (reac\w+) (\d+) (\d+)')

# Open the log file and read its contents
with open(log_file_path, 'r') as file:
    lines = file.readlines()

# Loop through each line and search for the pattern
for line in lines:
    match = pattern.search(line)
    if match:
        # Extract the reaction type and atom IDs
        reaction_type = match.group(1)
        atom_id_1 = int(match.group(2))
        atom_id_2 = int(match.group(3))
        
        # Calculate distance
        distance = abs(atom_id_1 - atom_id_2)
        
        # Get the corresponding reaction type from the map
        reaction_key = reaction_map[reaction_type]
        
        # Add the reaction event to the set of unique events
        reaction_distances[reaction_key].add((reaction_type, atom_id_1, atom_id_2))
        
        # Increment the count for the corresponding reaction type
        reaction_counts[reaction_key] += 1

labels = {'f1': 'Reaction A to U', 'f2': 'Reaction M to U', 'f3': 'Reaction U to A', 'f4': 'Reaction U to M'}

# Plot histograms of distances for each reaction type
plt.figure(figsize=(12, 8))
for reaction_type, distances in reaction_distances.items():
    plt.hist([abs(id1 - id2) for _, id1, id2 in distances], bins=20, alpha=0.7, label=f'{labels[reaction_type]}', density=True)

plt.title('Histogram of Distances for Each Reaction Type')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# Print the counts of each reaction type
for reaction_type, count in reaction_counts.items():
    print(f'{labels[reaction_type]} count: {count}')
# Out:
# Reaction A to U count: 22
# Reaction M to U count: 21
# Reaction U to A count: 22
# Reaction U to M count: 23
