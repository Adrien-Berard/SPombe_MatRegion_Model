# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import re

# %%
import re
import matplotlib.pyplot as plt

# Define the path to your log file
log_file_path = 'output.log'

# Initialize a dictionary to store the count of each reaction type
reaction_counts = {
    'f1': 0,
    'f2': 0,
    'f3': 0,
    'f4': 0
}

# Initialize dictionaries to store distances for each type of reaction
reaction_distances = {
    'f1': [],
    'f2': [],
    'f3': [],
    'f4': []
}

# Define a mapping from log reaction types to our reaction types
reaction_map = {
    'reacUM': 'f1',
    'reacMU': 'f2',
    'reacUA': 'f3',
    'reacAU': 'f4'
}

# Open the log file and read its contents
with open(log_file_path, 'r') as file:
    lines = file.readlines()

# Define a regex pattern to match lines containing reacting atom IDs and reaction types
pattern = re.compile(r'reacted_atom_IDs: (reac\w+) (\d+) (\d+)')

# Loop through each line and search for the pattern
for line in lines:
    match = pattern.search(line)
    if match:
        # Extract the reaction type and atom IDs
        reaction_type = match.group(1)
        atom_id_1 = int(match.group(2))
        atom_id_2 = int(match.group(3))
        
        # Calculate distance
        distance = abs(atom_id_1 - atom_id_2)
        
        # Get the corresponding reaction type from the map
        reaction_key = reaction_map[reaction_type]
        
        # Append distance to the appropriate reaction type
        reaction_distances[reaction_key].append(distance)
        
        # Increment the count for the corresponding reaction type
        reaction_counts[reaction_key] += 1

labels = {
    'f1': 'Reaction A to U',
    'f2': 'Reaction M to U',
    'f3': 'Reaction U to A',
    'f4': 'Reaction U to M'
}

# Plot histograms of distances for each reaction type
plt.figure(figsize=(12, 8))
for reaction_type, distances in reaction_distances.items():
    plt.hist(distances, bins=20, alpha=0.7, label=f'{labels[reaction_type]}', density=False)

plt.title('Histogram of Distances for Each Reaction Type')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# Print the counts of each reaction type
for reaction_type, count in reaction_counts.items():
    print(f'{labels[reaction_type]} count: {count}')
# Out:
# Reaction A to U count: 102
# Reaction M to U count: 133
# Reaction U to A count: 91
# Reaction U to M count: 115

# %%
import re
import matplotlib.pyplot as plt

# Define the path to your log file
log_file_path = 'output.log'

# Initialize a dictionary to store the count of each reaction type
reaction_counts = {
    'f1': 0,
    'f2': 0,
    'f3': 0,
    'f4': 0
}

# Initialize dictionaries to store distances for each type of reaction
reaction_distances = {
    'f1': [],
    'f2': [],
    'f3': [],
    'f4': []
}

# Define a mapping from log reaction types to our reaction types
reaction_map = {
    'reacAU': 'f1',
    'reacMU': 'f2',
    'reacUA': 'f3',
    'reacUM': 'f4'
}

# Open the log file and read its contents
with open(log_file_path, 'r') as file:
    lines = file.readlines()

# Define a regex pattern to match lines containing reacting atom IDs and reaction types
pattern = re.compile(r'reacted_atom_IDs: (reac\w+) (\d+) (\d+)')

# List to store reaction data for further use if needed
reaction_data = []

# Loop through each line and search for the pattern
for line in lines:
    match = pattern.search(line)
    if match:
        # Extract the reaction type and atom IDs
        reaction_type = match.group(1)
        atom_id_1 = int(match.group(2))
        atom_id_2 = int(match.group(3))
        
        # Calculate distance
        distance = abs(atom_id_1 - atom_id_2)
        
        # Get the corresponding reaction type from the map
        reaction_key = reaction_map[reaction_type]
        
        # Check if this reaction data already exists
        if (reaction_type, atom_id_1, atom_id_2, distance) not in reaction_data:
            # Append distance to the appropriate reaction type
            reaction_distances[reaction_key].append(distance)
            
            # Increment the count for the corresponding reaction type
            reaction_counts[reaction_key] += 1
    
            # Store the reaction data (including reaction type)
            reaction_data.append((reaction_type, atom_id_1, atom_id_2, distance))


labels = {
    'f1': 'Reaction A to U',
    'f2': 'Reaction M to U',
    'f3': 'Reaction U to A',
    'f4': 'Reaction U to M'
}

# Plot histograms of distances for each reaction type
plt.figure(figsize=(12, 8))
for reaction_type, distances in reaction_distances.items():
    plt.hist(distances, bins=20, alpha=0.7, label=f'{labels[reaction_type]}', density=True)

plt.title('Histogram of Distances for Each Reaction Type')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# Print the counts of each reaction type
for reaction_type, count in reaction_counts.items():
    print(f'{labels[reaction_type]} count: {count}')

# Print stored reaction data if needed
for reaction in reaction_data:
    print(f'Reaction {reaction[0]} between atom IDs {reaction[1]} and {reaction[2]} with distance {reaction[3]}')
# Out:
# Reaction A to U count: 106
# Reaction M to U count: 126
# Reaction U to A count: 88
# Reaction U to M count: 95
# Reaction reacUA between atom IDs 25 and 44 with distance 19
# Reaction reacMU between atom IDs 64 and 47 with distance 17
# Reaction reacUM between atom IDs 63 and 27 with distance 36
# Reaction reacAU between atom IDs 74 and 58 with distance 16
# Reaction reacUM between atom IDs 62 and 46 with distance 16
# Reaction reacUA between atom IDs 61 and 9 with distance 52
# Reaction reacUM between atom IDs 79 and 39 with distance 40
# Reaction reacMU between atom IDs 41 and 4 with distance 37
# Reaction reacMU between atom IDs 35 and 52 with distance 17
# Reaction reacUM between atom IDs 7 and 75 with distance 68
# Reaction reacUA between atom IDs 25 and 6 with distance 19
# Reaction reacAU between atom IDs 28 and 62 with distance 34
# Reaction reacUA between atom IDs 56 and 71 with distance 15
# Reaction reacUA between atom IDs 60 and 45 with distance 15
# Reaction reacUA between atom IDs 59 and 5 with distance 54
# Reaction reacMU between atom IDs 78 and 49 with distance 29
# Reaction reacAU between atom IDs 29 and 63 with distance 34
# Reaction reacMU between atom IDs 72 and 55 with distance 17
# Reaction reacAU between atom IDs 28 and 46 with distance 18
# Reaction reacAU between atom IDs 41 and 80 with distance 39
# Reaction reacUM between atom IDs 1 and 69 with distance 68
# Reaction reacUM between atom IDs 53 and 5 with distance 48
# Reaction reacUM between atom IDs 60 and 6 with distance 54
# Reaction reacAU between atom IDs 4 and 39 with distance 35
# Reaction reacAU between atom IDs 74 and 59 with distance 15
# Reaction reacAU between atom IDs 37 and 79 with distance 42
# Reaction reacUM between atom IDs 53 and 63 with distance 10
# Reaction reacMU between atom IDs 34 and 66 with distance 32
# Reaction reacUM between atom IDs 63 and 77 with distance 14
# Reaction reacMU between atom IDs 51 and 79 with distance 28
# Reaction reacAU between atom IDs 14 and 67 with distance 53
# Reaction reacAU between atom IDs 23 and 76 with distance 53
# Reaction reacUA between atom IDs 25 and 43 with distance 18
# Reaction reacMU between atom IDs 29 and 67 with distance 38
# Reaction reacUM between atom IDs 53 and 68 with distance 15
# Reaction reacUA between atom IDs 5 and 78 with distance 73
# Reaction reacAU between atom IDs 55 and 3 with distance 52
# Reaction reacMU between atom IDs 65 and 76 with distance 11
# Reaction reacUA between atom IDs 2 and 55 with distance 53
# Reaction reacUA between atom IDs 77 and 4 with distance 73
# Reaction reacMU between atom IDs 51 and 78 with distance 27
# Reaction reacMU between atom IDs 66 and 33 with distance 33
# Reaction reacUM between atom IDs 7 and 59 with distance 52
# Reaction reacAU between atom IDs 57 and 75 with distance 18
# Reaction reacUA between atom IDs 63 and 28 with distance 35
# Reaction reacMU between atom IDs 23 and 4 with distance 19
# Reaction reacUA between atom IDs 69 and 18 with distance 51
# Reaction reacMU between atom IDs 11 and 75 with distance 64
# Reaction reacAU between atom IDs 78 and 63 with distance 15
# Reaction reacAU between atom IDs 50 and 30 with distance 20
# Reaction reacUA between atom IDs 15 and 52 with distance 37
# Reaction reacAU between atom IDs 74 and 56 with distance 18
# Reaction reacUM between atom IDs 2 and 55 with distance 53
# Reaction reacUM between atom IDs 55 and 71 with distance 16
# Reaction reacUM between atom IDs 1 and 56 with distance 55
# Reaction reacAU between atom IDs 4 and 77 with distance 73
# Reaction reacUM between atom IDs 61 and 46 with distance 15
# Reaction reacMU between atom IDs 29 and 77 with distance 48
# Reaction reacUM between atom IDs 46 and 62 with distance 16
# Reaction reacUA between atom IDs 53 and 35 with distance 18
# Reaction reacMU between atom IDs 78 and 52 with distance 26
# Reaction reacMU between atom IDs 49 and 30 with distance 19
# Reaction reacUM between atom IDs 6 and 44 with distance 38
# Reaction reacUM between atom IDs 46 and 63 with distance 17
# Reaction reacAU between atom IDs 72 and 56 with distance 16
# Reaction reacUM between atom IDs 61 and 45 with distance 16
# Reaction reacUM between atom IDs 60 and 24 with distance 36
# Reaction reacUM between atom IDs 7 and 28 with distance 21
# Reaction reacAU between atom IDs 66 and 2 with distance 64
# Reaction reacUM between atom IDs 68 and 2 with distance 66
# Reaction reacMU between atom IDs 72 and 56 with distance 16
# Reaction reacMU between atom IDs 50 and 31 with distance 19
# Reaction reacAU between atom IDs 56 and 71 with distance 15
# Reaction reacUA between atom IDs 17 and 38 with distance 21
# Reaction reacUA between atom IDs 15 and 76 with distance 61
# Reaction reacMU between atom IDs 23 and 43 with distance 20
# Reaction reacUA between atom IDs 17 and 37 with distance 20
# Reaction reacUM between atom IDs 27 and 9 with distance 18
# Reaction reacUM between atom IDs 68 and 3 with distance 65
# Reaction reacAU between atom IDs 78 and 3 with distance 75
# Reaction reacUM between atom IDs 24 and 58 with distance 34
# Reaction reacUA between atom IDs 53 and 67 with distance 14
# Reaction reacAU between atom IDs 56 and 2 with distance 54
# Reaction reacUA between atom IDs 28 and 77 with distance 49
# Reaction reacMU between atom IDs 4 and 42 with distance 38
# Reaction reacUM between atom IDs 58 and 76 with distance 18
# Reaction reacUA between atom IDs 28 and 48 with distance 20
# Reaction reacMU between atom IDs 66 and 2 with distance 64
# Reaction reacAU between atom IDs 4 and 24 with distance 20
# Reaction reacMU between atom IDs 78 and 3 with distance 75
# Reaction reacAU between atom IDs 43 and 6 with distance 37
# Reaction reacUA between atom IDs 55 and 72 with distance 17
# Reaction reacAU between atom IDs 2 and 54 with distance 52
# Reaction reacMU between atom IDs 75 and 54 with distance 21
# Reaction reacMU between atom IDs 43 and 24 with distance 19
# Reaction reacUM between atom IDs 70 and 18 with distance 52
# Reaction reacMU between atom IDs 30 and 10 with distance 20
# Reaction reacAU between atom IDs 56 and 76 with distance 20
# Reaction reacMU between atom IDs 2 and 40 with distance 38
# Reaction reacAU between atom IDs 34 and 69 with distance 35
# Reaction reacUA between atom IDs 9 and 75 with distance 66
# Reaction reacUA between atom IDs 53 and 66 with distance 13
# Reaction reacAU between atom IDs 40 and 18 with distance 22
# Reaction reacMU between atom IDs 2 and 38 with distance 36
# Reaction reacUA between atom IDs 53 and 13 with distance 40
# Reaction reacMU between atom IDs 79 and 48 with distance 31
# Reaction reacUM between atom IDs 68 and 37 with distance 31
# Reaction reacMU between atom IDs 78 and 66 with distance 12
# Reaction reacUM between atom IDs 1 and 19 with distance 18
# Reaction reacAU between atom IDs 56 and 44 with distance 12
# Reaction reacMU between atom IDs 4 and 44 with distance 40
# Reaction reacAU between atom IDs 44 and 5 with distance 39
# Reaction reacAU between atom IDs 44 and 7 with distance 37
# Reaction reacAU between atom IDs 38 and 55 with distance 17
# Reaction reacUM between atom IDs 16 and 35 with distance 19
# Reaction reacUM between atom IDs 62 and 6 with distance 56
# Reaction reacUA between atom IDs 35 and 14 with distance 21
# Reaction reacUA between atom IDs 9 and 29 with distance 20
# Reaction reacMU between atom IDs 56 and 22 with distance 34
# Reaction reacAU between atom IDs 52 and 36 with distance 16
# Reaction reacAU between atom IDs 79 and 9 with distance 70
# Reaction reacMU between atom IDs 34 and 14 with distance 20
# Reaction reacMU between atom IDs 2 and 39 with distance 37
# Reaction reacUM between atom IDs 62 and 5 with distance 57
# Reaction reacUA between atom IDs 15 and 33 with distance 18
# Reaction reacUM between atom IDs 59 and 7 with distance 52
# Reaction reacAU between atom IDs 39 and 1 with distance 38
# Reaction reacAU between atom IDs 54 and 16 with distance 38
# Reaction reacUA between atom IDs 53 and 34 with distance 19
# Reaction reacAU between atom IDs 52 and 37 with distance 15
# Reaction reacMU between atom IDs 44 and 5 with distance 39
# Reaction reacAU between atom IDs 10 and 28 with distance 18
# Reaction reacUM between atom IDs 63 and 80 with distance 17
# Reaction reacMU between atom IDs 52 and 34 with distance 18
# Reaction reacMU between atom IDs 64 and 48 with distance 16
# Reaction reacMU between atom IDs 22 and 37 with distance 15
# Reaction reacMU between atom IDs 52 and 36 with distance 16
# Reaction reacMU between atom IDs 2 and 67 with distance 65
# Reaction reacAU between atom IDs 36 and 53 with distance 17
# Reaction reacAU between atom IDs 10 and 26 with distance 16
# Reaction reacUA between atom IDs 68 and 37 with distance 31
# Reaction reacUM between atom IDs 46 and 28 with distance 18
# Reaction reacUA between atom IDs 80 and 48 with distance 32
# Reaction reacAU between atom IDs 66 and 35 with distance 31
# Reaction reacMU between atom IDs 23 and 55 with distance 32
# Reaction reacMU between atom IDs 79 and 26 with distance 53
# Reaction reacUM between atom IDs 68 and 16 with distance 52
# Reaction reacMU between atom IDs 49 and 72 with distance 23
# Reaction reacAU between atom IDs 67 and 17 with distance 50
# Reaction reacAU between atom IDs 26 and 58 with distance 32
# Reaction reacUA between atom IDs 80 and 5 with distance 75
# Reaction reacMU between atom IDs 78 and 5 with distance 73
# Reaction reacAU between atom IDs 47 and 62 with distance 15
# Reaction reacMU between atom IDs 72 and 13 with distance 59
# Reaction reacMU between atom IDs 5 and 62 with distance 57
# Reaction reacAU between atom IDs 49 and 16 with distance 33
# Reaction reacMU between atom IDs 51 and 16 with distance 35
# Reaction reacUA between atom IDs 19 and 38 with distance 19
# Reaction reacUA between atom IDs 18 and 51 with distance 33
# Reaction reacUA between atom IDs 6 and 62 with distance 56
# Reaction reacUM between atom IDs 18 and 35 with distance 17
# Reaction reacMU between atom IDs 14 and 69 with distance 55
# Reaction reacAU between atom IDs 26 and 59 with distance 33
# Reaction reacAU between atom IDs 47 and 8 with distance 39
# Reaction reacMU between atom IDs 47 and 62 with distance 15
# Reaction reacUM between atom IDs 35 and 17 with distance 18
# Reaction reacUM between atom IDs 70 and 51 with distance 19
# Reaction reacMU between atom IDs 72 and 53 with distance 19
# Reaction reacUA between atom IDs 45 and 62 with distance 17
# Reaction reacUA between atom IDs 46 and 30 with distance 16
# Reaction reacAU between atom IDs 5 and 46 with distance 41
# Reaction reacAU between atom IDs 67 and 35 with distance 32
# Reaction reacAU between atom IDs 26 and 60 with distance 34
# Reaction reacUA between atom IDs 70 and 49 with distance 21
# Reaction reacUM between atom IDs 68 and 35 with distance 33
# Reaction reacAU between atom IDs 14 and 70 with distance 56
# Reaction reacAU between atom IDs 69 and 17 with distance 52
# Reaction reacUA between atom IDs 9 and 47 with distance 38
# Reaction reacUM between atom IDs 68 and 17 with distance 51
# Reaction reacUM between atom IDs 68 and 49 with distance 19
# Reaction reacUM between atom IDs 19 and 37 with distance 18
# Reaction reacAU between atom IDs 26 and 7 with distance 19
# Reaction reacAU between atom IDs 50 and 18 with distance 32
# Reaction reacMU between atom IDs 44 and 62 with distance 18
# Reaction reacUM between atom IDs 51 and 18 with distance 33
# Reaction reacAU between atom IDs 50 and 68 with distance 18
# Reaction reacMU between atom IDs 50 and 76 with distance 26
# Reaction reacUM between atom IDs 45 and 62 with distance 17
# Reaction reacAU between atom IDs 74 and 6 with distance 68
# Reaction reacAU between atom IDs 44 and 62 with distance 18
# Reaction reacMU between atom IDs 79 and 38 with distance 41
# Reaction reacUM between atom IDs 80 and 1 with distance 79
# Reaction reacUA between atom IDs 35 and 16 with distance 19
# Reaction reacUA between atom IDs 49 and 69 with distance 20
# Reaction reacAU between atom IDs 34 and 15 with distance 19
# Reaction reacAU between atom IDs 78 and 51 with distance 27
# Reaction reacUA between atom IDs 63 and 44 with distance 19
# Reaction reacUM between atom IDs 28 and 48 with distance 20
# Reaction reacAU between atom IDs 64 and 45 with distance 19
# Reaction reacUM between atom IDs 48 and 6 with distance 42
# Reaction reacUM between atom IDs 6 and 77 with distance 71
# Reaction reacUM between atom IDs 25 and 60 with distance 35
# Reaction reacUM between atom IDs 9 and 73 with distance 64
# Reaction reacUA between atom IDs 6 and 50 with distance 44
# Reaction reacMU between atom IDs 56 and 21 with distance 35
# Reaction reacUM between atom IDs 63 and 47 with distance 16
# Reaction reacAU between atom IDs 26 and 61 with distance 35
# Reaction reacMU between atom IDs 26 and 61 with distance 35
# Reaction reacMU between atom IDs 36 and 69 with distance 33
# Reaction reacMU between atom IDs 65 and 50 with distance 15
# Reaction reacUA between atom IDs 28 and 50 with distance 22
# Reaction reacUM between atom IDs 49 and 29 with distance 20
# Reaction reacUA between atom IDs 80 and 38 with distance 42
# Reaction reacMU between atom IDs 10 and 30 with distance 20
# Reaction reacMU between atom IDs 14 and 71 with distance 57
# Reaction reacAU between atom IDs 64 and 77 with distance 13
# Reaction reacMU between atom IDs 31 and 51 with distance 20
# Reaction reacUM between atom IDs 28 and 46 with distance 18
# Reaction reacMU between atom IDs 79 and 44 with distance 35
# Reaction reacUM between atom IDs 60 and 7 with distance 53
# Reaction reacUM between atom IDs 18 and 70 with distance 52
# Reaction reacUA between atom IDs 17 and 71 with distance 54
# Reaction reacAU between atom IDs 30 and 48 with distance 18
# Reaction reacUA between atom IDs 77 and 5 with distance 72
# Reaction reacAU between atom IDs 43 and 25 with distance 18
# Reaction reacMU between atom IDs 30 and 48 with distance 18
# Reaction reacUA between atom IDs 46 and 78 with distance 32
# Reaction reacMU between atom IDs 64 and 78 with distance 14
# Reaction reacAU between atom IDs 53 and 73 with distance 20
# Reaction reacUA between atom IDs 28 and 61 with distance 33
# Reaction reacUM between atom IDs 80 and 38 with distance 42
# Reaction reacAU between atom IDs 79 and 46 with distance 33
# Reaction reacAU between atom IDs 76 and 6 with distance 70
# Reaction reacMU between atom IDs 43 and 25 with distance 18
# Reaction reacAU between atom IDs 30 and 49 with distance 19
# Reaction reacUA between atom IDs 19 and 4 with distance 15
# Reaction reacMU between atom IDs 3 and 20 with distance 17
# Reaction reacMU between atom IDs 79 and 46 with distance 33
# Reaction reacMU between atom IDs 76 and 8 with distance 68
# Reaction reacUA between atom IDs 80 and 66 with distance 14
# Reaction reacUM between atom IDs 37 and 1 with distance 36
# Reaction reacMU between atom IDs 36 and 68 with distance 32
# Reaction reacMU between atom IDs 32 and 49 with distance 17
# Reaction reacMU between atom IDs 26 and 7 with distance 19
# Reaction reacUM between atom IDs 9 and 75 with distance 66
# Reaction reacUA between atom IDs 47 and 30 with distance 17
# Reaction reacUM between atom IDs 70 and 16 with distance 54
# Reaction reacMU between atom IDs 52 and 4 with distance 48
# Reaction reacUM between atom IDs 70 and 50 with distance 20
# Reaction reacMU between atom IDs 46 and 62 with distance 16
# Reaction reacAU between atom IDs 20 and 38 with distance 18
# Reaction reacAU between atom IDs 12 and 29 with distance 17
# Reaction reacUM between atom IDs 19 and 38 with distance 19
# Reaction reacMU between atom IDs 22 and 5 with distance 17
# Reaction reacAU between atom IDs 46 and 27 with distance 19
# Reaction reacUA between atom IDs 18 and 72 with distance 54
# Reaction reacAU between atom IDs 51 and 16 with distance 35
# Reaction reacUM between atom IDs 18 and 71 with distance 53
# Reaction reacMU between atom IDs 49 and 16 with distance 33
# Reaction reacUM between atom IDs 35 and 66 with distance 31
# Reaction reacAU between atom IDs 46 and 60 with distance 14
# Reaction reacUM between atom IDs 35 and 15 with distance 20
# Reaction reacAU between atom IDs 30 and 63 with distance 33
# Reaction reacAU between atom IDs 4 and 38 with distance 34
# Reaction reacUA between atom IDs 37 and 20 with distance 17
# Reaction reacUM between atom IDs 28 and 45 with distance 17
# Reaction reacUM between atom IDs 70 and 20 with distance 50
# Reaction reacUA between atom IDs 77 and 48 with distance 29
# Reaction reacAU between atom IDs 69 and 37 with distance 32
# Reaction reacUA between atom IDs 1 and 67 with distance 66
# Reaction reacAU between atom IDs 74 and 50 with distance 24
# Reaction reacMU between atom IDs 25 and 58 with distance 33
# Reaction reacUM between atom IDs 20 and 37 with distance 17
# Reaction reacMU between atom IDs 26 and 60 with distance 34
# Reaction reacUA between atom IDs 75 and 7 with distance 68
# Reaction reacMU between atom IDs 52 and 73 with distance 21
# Reaction reacUM between atom IDs 35 and 67 with distance 32
# Reaction reacUM between atom IDs 71 and 50 with distance 21
# Reaction reacUA between atom IDs 50 and 73 with distance 23
# Reaction reacUA between atom IDs 71 and 51 with distance 20
# Reaction reacUA between atom IDs 20 and 39 with distance 19
# Reaction reacAU between atom IDs 68 and 35 with distance 33
# Reaction reacAU between atom IDs 3 and 37 with distance 34
# Reaction reacAU between atom IDs 30 and 47 with distance 17
# Reaction reacMU between atom IDs 68 and 35 with distance 33
# Reaction reacMU between atom IDs 78 and 62 with distance 16
# Reaction reacUA between atom IDs 45 and 78 with distance 33
# Reaction reacUM between atom IDs 19 and 72 with distance 53
# Reaction reacUA between atom IDs 50 and 74 with distance 24
# Reaction reacAU between atom IDs 46 and 66 with distance 20
# Reaction reacUA between atom IDs 50 and 16 with distance 34
# Reaction reacUA between atom IDs 72 and 21 with distance 51
# Reaction reacAU between atom IDs 8 and 75 with distance 67
# Reaction reacUM between atom IDs 70 and 37 with distance 33
# Reaction reacMU between atom IDs 46 and 78 with distance 32
# Reaction reacMU between atom IDs 34 and 48 with distance 14
# Reaction reacMU between atom IDs 79 and 63 with distance 16
# Reaction reacUA between atom IDs 72 and 52 with distance 20
# Reaction reacMU between atom IDs 35 and 16 with distance 19
# Reaction reacUA between atom IDs 80 and 65 with distance 15
# Reaction reacUA between atom IDs 15 and 49 with distance 34
# Reaction reacAU between atom IDs 36 and 72 with distance 36
# Reaction reacUA between atom IDs 37 and 68 with distance 31
# Reaction reacAU between atom IDs 2 and 67 with distance 65
# Reaction reacUM between atom IDs 15 and 49 with distance 34
# Reaction reacMU between atom IDs 76 and 27 with distance 49
# Reaction reacMU between atom IDs 5 and 38 with distance 33
# Reaction reacMU between atom IDs 78 and 45 with distance 33
# Reaction reacMU between atom IDs 5 and 74 with distance 69
# Reaction reacUM between atom IDs 17 and 51 with distance 34
# Reaction reacUA between atom IDs 49 and 16 with distance 33
# Reaction reacAU between atom IDs 35 and 49 with distance 14
# Reaction reacAU between atom IDs 58 and 28 with distance 30
# Reaction reacUM between atom IDs 77 and 28 with distance 49
# Reaction reacUA between atom IDs 50 and 5 with distance 45
# Reaction reacMU between atom IDs 26 and 6 with distance 20
# Reaction reacUA between atom IDs 20 and 38 with distance 18
# Reaction reacAU between atom IDs 69 and 18 with distance 51
# Reaction reacMU between atom IDs 34 and 16 with distance 18
# Reaction reacUM between atom IDs 80 and 65 with distance 15
# Reaction reacAU between atom IDs 16 and 70 with distance 54
# Reaction reacUA between atom IDs 1 and 40 with distance 39
# Reaction reacAU between atom IDs 16 and 51 with distance 35
# Reaction reacMU between atom IDs 79 and 29 with distance 50
# Reaction reacMU between atom IDs 73 and 51 with distance 22
# Reaction reacAU between atom IDs 64 and 80 with distance 16
# Reaction reacMU between atom IDs 6 and 50 with distance 44
# Reaction reacUA between atom IDs 15 and 48 with distance 33
# Reaction reacUA between atom IDs 20 and 4 with distance 16
# Reaction reacAU between atom IDs 50 and 20 with distance 30
# Reaction reacAU between atom IDs 63 and 1 with distance 62
# Reaction reacUA between atom IDs 15 and 69 with distance 54
# Reaction reacAU between atom IDs 36 and 17 with distance 19
# Reaction reacUA between atom IDs 28 and 76 with distance 48
# Reaction reacUM between atom IDs 71 and 17 with distance 54
# Reaction reacUM between atom IDs 75 and 52 with distance 23
# Reaction reacMU between atom IDs 12 and 76 with distance 64
# Reaction reacMU between atom IDs 50 and 18 with distance 32
# Reaction reacAU between atom IDs 47 and 65 with distance 18
# Reaction reacUM between atom IDs 19 and 40 with distance 21
# Reaction reacMU between atom IDs 64 and 80 with distance 16
# Reaction reacAU between atom IDs 27 and 77 with distance 50
# Reaction reacAU between atom IDs 79 and 28 with distance 51
# Reaction reacUM between atom IDs 9 and 28 with distance 19
# Reaction reacMU between atom IDs 7 and 58 with distance 51
# Reaction reacMU between atom IDs 14 and 49 with distance 35
# Reaction reacMU between atom IDs 58 and 5 with distance 53
# Reaction reacUM between atom IDs 38 and 1 with distance 37
# Reaction reacMU between atom IDs 58 and 25 with distance 33
# Reaction reacMU between atom IDs 47 and 76 with distance 29
# Reaction reacMU between atom IDs 78 and 46 with distance 32
# Reaction reacMU between atom IDs 25 and 59 with distance 34
# Reaction reacMU between atom IDs 60 and 24 with distance 36
# Reaction reacUM between atom IDs 52 and 72 with distance 20
# Reaction reacMU between atom IDs 16 and 69 with distance 53
# Reaction reacUM between atom IDs 40 and 21 with distance 19
# Reaction reacUM between atom IDs 72 and 4 with distance 68
# Reaction reacMU between atom IDs 27 and 62 with distance 35
# Reaction reacMU between atom IDs 26 and 44 with distance 18
# Reaction reacAU between atom IDs 2 and 38 with distance 36
# Reaction reacUM between atom IDs 28 and 75 with distance 47
# Reaction reacUM between atom IDs 28 and 77 with distance 49
# Reaction reacUA between atom IDs 52 and 69 with distance 17
# Reaction reacUA between atom IDs 37 and 18 with distance 19
# Reaction reacAU between atom IDs 73 and 52 with distance 21
# Reaction reacUA between atom IDs 40 and 2 with distance 38
# Reaction reacMU between atom IDs 8 and 74 with distance 66
# Reaction reacMU between atom IDs 74 and 48 with distance 26
# Reaction reacAU between atom IDs 76 and 28 with distance 48
# Reaction reacMU between atom IDs 47 and 64 with distance 17
# Reaction reacMU between atom IDs 79 and 65 with distance 14
# Reaction reacMU between atom IDs 23 and 41 with distance 18
# Reaction reacAU between atom IDs 47 and 77 with distance 30
# Reaction reacUA between atom IDs 72 and 6 with distance 66
# Reaction reacMU between atom IDs 48 and 70 with distance 22
# Reaction reacMU between atom IDs 76 and 6 with distance 70
# Reaction reacMU between atom IDs 70 and 2 with distance 68
# Reaction reacUM between atom IDs 40 and 3 with distance 37
# Reaction reacMU between atom IDs 25 and 61 with distance 36
# Reaction reacUA between atom IDs 21 and 41 with distance 20
# Reaction reacAU between atom IDs 2 and 71 with distance 69
# Reaction reacAU between atom IDs 70 and 4 with distance 66
# Reaction reacMU between atom IDs 16 and 35 with distance 19
# Reaction reacMU between atom IDs 33 and 15 with distance 18
# Reaction reacUM between atom IDs 37 and 71 with distance 34
# Reaction reacMU between atom IDs 76 and 50 with distance 26
# Reaction reacUM between atom IDs 3 and 72 with distance 69
# Reaction reacMU between atom IDs 7 and 77 with distance 70
# Reaction reacUM between atom IDs 21 and 41 with distance 20
# Reaction reacMU between atom IDs 26 and 43 with distance 17
# Reaction reacUA between atom IDs 37 and 73 with distance 36
# Reaction reacMU between atom IDs 68 and 51 with distance 17
# Reaction reacAU between atom IDs 74 and 40 with distance 34
# Reaction reacMU between atom IDs 53 and 10 with distance 43
# Reaction reacMU between atom IDs 5 and 40 with distance 35
# Reaction reacUA between atom IDs 3 and 48 with distance 45
# Reaction reacUM between atom IDs 37 and 17 with distance 20
# Reaction reacUM between atom IDs 75 and 4 with distance 71
# Reaction reacUA between atom IDs 72 and 2 with distance 70
# Reaction reacAU between atom IDs 74 and 4 with distance 70
# Reaction reacUA between atom IDs 17 and 55 with distance 38
# Reaction reacUA between atom IDs 17 and 36 with distance 19
# Reaction reacUA between atom IDs 41 and 22 with distance 19
# Reaction reacMU between atom IDs 60 and 22 with distance 38
# Reaction reacAU between atom IDs 22 and 3 with distance 19
# Reaction reacAU between atom IDs 44 and 1 with distance 43
# Reaction reacMU between atom IDs 16 and 52 with distance 36
# Reaction reacUM between atom IDs 37 and 73 with distance 36
# Reaction reacUA between atom IDs 37 and 74 with distance 37
# Reaction reacMU between atom IDs 58 and 9 with distance 49
# Reaction reacUM between atom IDs 37 and 18 with distance 19
# Reaction reacMU between atom IDs 16 and 55 with distance 39
# Reaction reacUM between atom IDs 73 and 38 with distance 35
# Reaction reacUA between atom IDs 37 and 16 with distance 21
# Reaction reacAU between atom IDs 76 and 72 with distance 4

# %%
import re
import matplotlib.pyplot as plt

# Define the path to your log file
log_file_path = 'output.log'

# Initialize dictionaries to store counts and distances for each type of reaction
reaction_counts = {'f1': 0, 'f2': 0, 'f3': 0, 'f4': 0}
reaction_distances = {'f1': set(), 'f2': set(), 'f3': set(), 'f4': set()}

# Define a mapping from log reaction types to our reaction types
reaction_map = {'reacAU': 'f1', 'reacMU': 'f2', 'reacUA': 'f3', 'reacUM': 'f4'}

# Define a regex pattern to match lines containing reacting atom IDs and reaction types
pattern = re.compile(r'reacted_atom_IDs: (reac\w+) (\d+) (\d+)')

# Open the log file and read its contents
with open(log_file_path, 'r') as file:
    lines = file.readlines()

# Loop through each line and search for the pattern
for line in lines:
    match = pattern.search(line)
    if match:
        # Extract the reaction type and atom IDs
        reaction_type = match.group(1)
        atom_id_1 = int(match.group(2))
        atom_id_2 = int(match.group(3))
        
        # Calculate distance
        distance = abs(atom_id_1 - atom_id_2)
        
        # Get the corresponding reaction type from the map
        reaction_key = reaction_map[reaction_type]
        
        # Check if this reaction data already exists
        if (atom_id_1, atom_id_2, distance) not in reaction_distances[reaction_key]:
            # Append distance to the appropriate reaction type
            reaction_distances[reaction_key].add((atom_id_1, atom_id_2, distance))
            
            # Increment the count for the corresponding reaction type
            reaction_counts[reaction_key] += 1

labels = {'f1': 'Reaction A to U', 'f2': 'Reaction M to U', 'f3': 'Reaction U to A', 'f4': 'Reaction U to M'}

# Plot histograms of distances for each reaction type
plt.figure(figsize=(12, 8))
for reaction_type, distances in reaction_distances.items():
    plt.hist([distance[2] for distance in distances], bins=20, alpha=0.7, label=f'{labels[reaction_type]}', density=True)

plt.title('Histogram of Distances for Each Reaction Type')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# Print the counts of each reaction type
for reaction_type, count in reaction_counts.items():
    print(f'{labels[reaction_type]} count: {count}')
# Out:
# Reaction A to U count: 106
# Reaction M to U count: 126
# Reaction U to A count: 88
# Reaction U to M count: 95

# %%
import re
import matplotlib.pyplot as plt

# Define the path to your log file
log_file_path = 'output.log'

# Initialize dictionaries to store counts and distances for each type of reaction
reaction_counts = {'f1': 0, 'f2': 0, 'f3': 0, 'f4': 0}
reaction_distances = {'f1': set(), 'f2': set(), 'f3': set(), 'f4': set()}

# Define a mapping from log reaction types to our reaction types
reaction_map = {'reacAU': 'f1', 'reacMU': 'f2', 'reacUA': 'f3', 'reacUM': 'f4'}

# Define a regex pattern to match lines containing reacting atom IDs and reaction types
pattern = re.compile(r'reacted_atom_IDs: (reac\w+) (\d+) (\d+)')

# Open the log file and read its contents
with open(log_file_path, 'r') as file:
    lines = file.readlines()

# Loop through each line and search for the pattern
for line in lines:
    match = pattern.search(line)
    if match:
        # Extract the reaction type and atom IDs
        reaction_type = match.group(1)
        atom_id_1 = int(match.group(2))
        atom_id_2 = int(match.group(3))
        
        # Calculate distance
        distance = abs(atom_id_1 - atom_id_2)
        
        # Get the corresponding reaction type from the map
        reaction_key = reaction_map[reaction_type]
        
        # Add the reaction event to the set of unique events
        reaction_distances[reaction_key].add((reaction_type, atom_id_1, atom_id_2))
        
        # Increment the count for the corresponding reaction type
        reaction_counts[reaction_key] += 1

labels = {'f1': 'Reaction A to U', 'f2': 'Reaction M to U', 'f3': 'Reaction U to A', 'f4': 'Reaction U to M'}

# Plot histograms of distances for each reaction type
plt.figure(figsize=(12, 8))
for reaction_type, distances in reaction_distances.items():
    plt.hist([abs(id1 - id2) for _, id1, id2 in distances], bins=20, alpha=0.7, label=f'{labels[reaction_type]}', density=True)

plt.title('Histogram of Distances for Each Reaction Type')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# Print the counts of each reaction type
for reaction_type, count in reaction_counts.items():
    print(f'{labels[reaction_type]} count: {count}')
# Out:
# Reaction A to U count: 115
# Reaction M to U count: 133
# Reaction U to A count: 92
# Reaction U to M count: 102
